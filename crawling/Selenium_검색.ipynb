# %%
 # !pip3 install selenium==3.141
 # !apt-get update
 # !apt install chromium-chromedriver
# Out:
# Collecting selenium==3.141
#   Downloading selenium-3.141.0-py2.py3-none-any.whl (904 kB)
#      |████████████████████████████████| 904 kB 2.7 MB/s
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from selenium==3.141) (1.24.3)
# Installing collected packages: selenium
# Successfully installed selenium-3.141.0
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Ign:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Get:3 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Ign:4 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Get:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release [696 B]
# Hit:6 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:7 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease [15.9 kB]
# Hit:8 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Get:9 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release.gpg [836 B]
# Get:10 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Get:12 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Packages [813 kB]
# Hit:13 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Get:14 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Hit:15 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease
# Hit:16 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Get:17 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 Packages [2,867 kB]
# Get:18 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main Sources [1,812 kB]
# Get:19 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 Packages [2,222 kB]
# Get:20 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main amd64 Packages [928 kB]
# Fetched 8,916 kB in 6s (1,458 kB/s)
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   chromium-browser chromium-browser-l10n chromium-codecs-ffmpeg-extra
# Suggested packages:
#   webaccounts-chromium-extension unity-chromium-extension
# The following NEW packages will be installed:
#   chromium-browser chromium-browser-l10n chromium-chromedriver
#   chromium-codecs-ffmpeg-extra
# 0 upgraded, 4 newly installed, 0 to remove and 39 not upgraded.
# Need to get 94.0 MB of archives.
# After this operation, 324 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 chromium-codecs-ffmpeg-extra amd64 95.0.4638.69-0ubuntu0.18.04.1 [1,135 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 chromium-browser amd64 95.0.4638.69-0ubuntu0.18.04.1 [83.6 MB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 chromium-browser-l10n all 95.0.4638.69-0ubuntu0.18.04.1 [4,249 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 chromium-chromedriver amd64 95.0.4638.69-0ubuntu0.18.04.1 [4,986 kB]
# Fetched 94.0 MB in 10s (9,457 kB/s)
# Selecting previously unselected package chromium-codecs-ffmpeg-extra.
# (Reading database ... 155222 files and directories currently installed.)
# Preparing to unpack .../chromium-codecs-ffmpeg-extra_95.0.4638.69-0ubuntu0.18.04.1_amd64.deb ...
# Unpacking chromium-codecs-ffmpeg-extra (95.0.4638.69-0ubuntu0.18.04.1) ...
# Selecting previously unselected package chromium-browser.
# Preparing to unpack .../chromium-browser_95.0.4638.69-0ubuntu0.18.04.1_amd64.deb ...
# Unpacking chromium-browser (95.0.4638.69-0ubuntu0.18.04.1) ...
# Selecting previously unselected package chromium-browser-l10n.
# Preparing to unpack .../chromium-browser-l10n_95.0.4638.69-0ubuntu0.18.04.1_all.deb ...
# Unpacking chromium-browser-l10n (95.0.4638.69-0ubuntu0.18.04.1) ...
# Selecting previously unselected package chromium-chromedriver.
# Preparing to unpack .../chromium-chromedriver_95.0.4638.69-0ubuntu0.18.04.1_amd64.deb ...
# Unpacking chromium-chromedriver (95.0.4638.69-0ubuntu0.18.04.1) ...
# Setting up chromium-codecs-ffmpeg-extra (95.0.4638.69-0ubuntu0.18.04.1) ...
# Setting up chromium-browser (95.0.4638.69-0ubuntu0.18.04.1) ...
# update-alternatives: using /usr/bin/chromium-browser to provide /usr/bin/x-www-browser (x-www-browser) in auto mode
# update-alternatives: using /usr/bin/chromium-browser to provide /usr/bin/gnome-www-browser (gnome-www-browser) in auto mode
# Setting up chromium-chromedriver (95.0.4638.69-0ubuntu0.18.04.1) ...
# Setting up chromium-browser-l10n (95.0.4638.69-0ubuntu0.18.04.1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Processing triggers for hicolor-icon-theme (0.17-2) ...
# Processing triggers for mime-support (3.60ubuntu1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.3) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.7/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link

# %%
from selenium import webdriver
from urllib.request import urlopen
from bs4 import BeautifulSoup as bs
from urllib.parse import quote_plus
from selenium.webdriver.common.keys import Keys
import time

# url = 'https://search.naver.com/search.naver?where=image&sm=tab_jum&query='
# kword = input('검색어를 입력하세요 : ')
base_url = 'https://pedia.watcha.com/ko-KR/search?query=%EC%A7%80%EA%B5%AC%EB%A5%BC%20%EC%A7%80%EC%BC%9C%EB%9D%BC&category=contents'

searchkeyword = '지구를 지켜라'

base_url = 'https://pedia.watcha.com/ko-KR/search?query=' + searchkeyword + '&category=contents'

# %%
chrome_options = webdriver.ChromeOptions()

chrome_options.add_argument('--headless') #내부 창을 띄울 수 없으므로 설정

chrome_options.add_argument('--no-sandbox')

chrome_options.add_argument('--disable-dev-shm-usage')

driver = webdriver.Chrome('chromedriver',options=chrome_options)

driver.get(base_url)

# %%
#로그인 팝업

driver.find_element_by_css_selector('#root > div > div.css-1xm32e0 > header > nav > div > div > ul > li:nth-child(6) > button').click()

# %%
#로그인하기 

driver.find_element_by_name('email').send_keys('bleachshot@gmail.com')
driver.find_element_by_name('password').send_keys('dkfkqldk12!@')
driver.find_element_by_class_name("css-qr0uqd-StylelessButton").click()

# %%
# 검색 리스트에서 클릭
driver.find_element_by_xpath('//*[@id="root"]/div/div[1]/section/section/div[3]/div[1]/section/section[1]/div/div[1]/div/ul/li[1]/a/div[1]/div[1]/img').click()

# %%
# 영화 세부사항?
sample = driver.find_element_by_xpath('//*[@id="root"]/div/div[1]/section/div/div[2]/div/section/div[2]/div/div/div/div/div[1]').text

print(sample)
# Out:
# 2003 ・ 코미디/액션/스릴러 ・ 한국

# %%
# 리뷰 더보기 클릭
driver.find_element_by_xpath('//*[@id="root"]/div/div[1]/section/div/div[2]/div/div/div/div[1]/div[1]/div/div/section[5]/div[1]/div/header/div/div/a').click()

# %%
body = driver.find_element_by_tag_name('body')

# %%
# 페이지 다운시켜서 더 많은 리스트가 나오게 한다
for i in range(100):
    body.send_keys(Keys.PAGE_DOWN)
    time.sleep(0.33)

# %%
# 리뷰 내용
comments = driver.find_elements_by_xpath('//*[@id="root"]/div/div[1]/section/section/div/div/div/ul/div[*]/div[2]/div/span')

# 별점
rates = driver.find_elements_by_xpath(' //*[@id="root"]/div/div[1]/section/section/div/div/div/ul/div[*]/div[1]/div[2]/span')

data_size = len(comments)

print(data_size)

result = [["" for col in range(2)] for row in range(data_size)]

for i in range(0,data_size):
  result[i][0] = comments[i].text
  result[i][1] = rates[i].text
# Out:
# 99

# %%
for i in range(0,data_size):
  print(result[i][0])
  print(result[i][1])

print(data_size)
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# 진짜고 아니고가 중요한게 아니다.
#
# 오늘 지구는 안녕하십니까
# 1.0
# 장준환이라 기대했는데...너무 심하게 노잼이라 당황스러울 정도
# 4.0
# 마취됐어 아프지않아 ! !!
# 5.0
# B급 영화 감성이 좋다
# 4.5
# 세상이 무너질 때, 눈물이 나더라.
# 하긴, 내 세상은 진즉에 무너졌다.
# 4.0
# 짓밟힌 삶 속에 생긴 소박한 목표
# 1.5
# 왜 명작이란 거지? 잔인한 부분이 많았음. 마지막 장면은 흥미롭다
# 4.5
# 기괴갑.. 근데 좋다..
# 병구야 고생했다,,ㅠㅠ
# 3.0
# 순수성이 참 사람 기분 이상하게 만든다
# 3.0
#
# 4.0
# 처음 이 영화를 보기 직전까지도 두 시간 후 내 스스로가 감동을 받을 거라고는 전혀 생각하지 못했다.
# 4.0
#
# 4.5
# 다들 고생했다 그리고 잘했다
# 받아라 4.5점
# 4.5
# 21.05.01
# 4.0
# 으악! 으악! 으악!!!!!!!!
# 포스터 바꿔 이 사람들아!!!!!!!!
# 4.0
# 사람이 희생당하는 이유가 사람때문이 아니길 빌며..
# 4.0
# 이젠 병구만 생각해도 눈물이 난다
# 그를 위로해줄 사람은 아무도 없다
# 2.0
#
# 3.0
# 참신하다. 잘만든 b급 감성 영화
# 말씨가 지금의 말씨랑 조금 다른게 느껴져서 신기했다
# 그거말고는 뭐 딱히....다른 감상은 없네요
# 아 신하균 연기 잘하네
# 다른 사람 코멘트 중 “과소평가 당했다는 이유로 과대평가된 느낌”이라는거에 100퍼센트 공감한다
# 3.5
# -2020년 3월 2일 넷플릭스
# 4.5
# 다들 마음속에 더러운 외계인 놈 하나씩 지니고 있지 않습니껴
# 3.5
# 냉소는 자조 섞인 자충수가 되기도 한다.
# 4.5
# 소외된 지구인들에게
# 5.0
# 한 사람은 하나의 행성이야
# 2.0
# 이런 게 수작이면 딱히 이해하고 싶지 않아...
# 4.0
# 백윤식씨 성대 안녕하신가요.. 결말 때문에 0.5점 더 얹습니다
# 4.5
# 웰메이드 블랙 코미디
# 3.5
# 왜 아리에스터가 눈독들이는지 너무 잘 알 것 같음
# 0.5
# 이게 뭐여,, ㅋㅋㅋ
# 뭔 꼴뚜기왕자만 찾다 끝나
# 두번 다시 보고싶지 않은 영화
# 아까운 내 시간
# 신하균 연기 빼면 0점도 아깝다
# 5.0
# 괴물보고 신하균 배우 필모 깨다가 알게된 영화
# 모든게 이걸 보기 위함이었나 싶을 정도로 좋다
# 2.0
# 솔직히 뭐가 명작이라는지 모르겠는
# 4.0
# B급인데 B+
# 병구를 미치게 만든 것은 누구인가 무엇인가 한참 생각해보게 된다.
# 4.5
# 감독의 상상력이 놀랍도록 신박하다.
# 내 취향저격은 덤.
# 신하균은 역시 사이코연기가 제일 잘 어울린다.
# 3.5
# 내 기대가 컸나 보다
# 4.5
# 마취됐어! 아프지 않아
# 4.0
# 병구를 지켜라!
# 4.5
# 인류에 대한 염세와 한탄을 기발한 상상력으로 유쾌하게 풀어나간다.
# 4.0
# 신하균.. 진짜 젊다
# 3.0
# 약자는 언제나 미친 사람 취급을 당한다.
# 그런 의미에서 이 영화는 처음부터 끝까지 약자를 비웃고있다.
# 4.5
# 장준환 감독은 아직도 이 작품을 넘어선 적이 없다
# 5.0
# 저주받은 걸작??
#
# 시대를 아우른 명작!!
# 5.0
# 비슷한 다른 영화가 필요하지만 아직까진 못찾겠다
# 5.0
# 인생영화
#
# 아무것도 못하다가 성과만 챙기기 급급하였단 경찰
# 오히려 전직 경찰이 가장 일을 잘한다는 아이러니
#
# 아무도 신경쓰지 않은 밑바닥 인생의 정신병자인 병구가 걱정하는건 엄마와 지구..
#
# 소외 받아 본 사람은 소외 받아 삐뚤어져본 사람은 병구의 마음을 지키기 얼마나 어려운지 알고 있을 것이다
#
# 그러나 아무도 알아줒 않는 병구의 노력
#
# 모든 것이 그렇게 끝난다
# 4.0
# 선 넘은 블랙 코미디
# 3.0
# 병구가 미친줄 알았는데 아니었고 진짜 미친건 세상이랑 이 영화에 5점준 사람들인거 같음 아니면 그걸 이해하지 못하는 내가 미쳤나? 아무튼 미쳐있다
# 4.0
# 그래, 외계인이 괴롭히는거다.
# 4.0
# 누가 좀 이거 다시 리메이크해서 개봉해주세요 시대를 앞선 영화에요
# 3.5
# 구타심페소생술에 웃어버렸는데...
# 갑자기 스릴도느꼈다.
# 병구가 미친것을 이해하게되면서 짠하고 갑자기 엥
#
# 마지막에는 왜 슬프지...
#
# 참 여러가지로 요상한 영화
#
# 지구멸망엔딩까지 완벽!
# 5.0
# 이런 미친
# 4.5
# 비운의 명작
# 4.5
# 컬트 영화가 주는 스페셜리티
# 4.0
# 그리스의 비극적 주인공이 연상되는 기구한 삶. 기술이 잡음이 될 상황에서도 완결성을 갖추고 막을 내린다.
# 4.0
# 계급 투쟁을 은유하는 방식이 신선하고 날카롭다.
# 3.5
# 전반부에 속음. ㅋㅋㅋㅋㅋ
# 큐브릭 따위 병신력으로 압도 ㅋㅋㅋㅋㅋㅋ
# 3.0
# 이토록 예측 안 되는 영화는 처음이다
# 2.5
# 저 상황에 어떻게 안미치고 버티겠냐
# 3.0
# 병구의 아포리아는 지구를 파멸에 이르게 만든다. 외계인의 장대한 계획이라는 벽 앞에서 총을 격발시킬 힘이 인류에게 있다고 믿으며, 그 인간의 힘을 똑같은 인간이 저지하는 한계 역시 인정한다(체념한다). 벽을 넘는 잠재력과 이를 좌절시키는 자제력 사이에서 아포리아는 계속된다. 그래서 와장창 지구 멸망 엔딩이 당도한다. 성급하지만 그 질긴 모순을 부정할 힘은 남아있지 않기에 고개를 끄덕일 수밖에 없다.
# 3.5
# 의미가 보이는 괴작은 명작이 된다.
# 4.5
# 이 영화를 눈물 없이 보는 건 불가능하다.
# 4.5
# '미친 척 그만해, 이 미친놈아'
# 3.5
# 이걸 어떻게 투자 받지...?
# 4.0
# 고민하는 관객을 우습게 만드는
# 3.0
# 백터맨 절망편같았다
# 4.5
# 여러면에서 미친영화다
# 4.5
# 공부하려고 켰다가 빠져들었다. 차라리 외계인 탓이라면 더 납득하기 쉬울까?  뻔하지 않은 전개 방식과 독특한 유머, 탄탄하게 진행되는 스토리..  그만 외면하고 싶게 만드는 좋은 영화.
# 0.5
# 영화가 망한건 홍보의 문제가 아닌 재미의 문제
# 5.0
# 적어도 1세기는 지나야 이 영화보다 독창적인 영화가 나올 것이다.
# 3.5
# 18년 만에 완결을 봤네
# 3.5
# 이렇게 될 때까지 뭐했어
# 지구가 망할 때까지 우린 아무 것도 못할거다
#
# 그저 멍하다
# 웃긴데 이상하고 무서우며
# 마음 아프면서 따뜻하기도 하고
# 재미있다고 말할 순 없는데 안보면 안될 것 같은 영화
#
# 황당한 감정들이 계속해서 지나가는 이 영화를 어떻게 만들었지라는 생각 밖에 안든다
# 4.0
# 거의 17년만에 다시 본 영화.
# 늘 내가 영화 추천할때 1순위로 이야기한 영화.
# 다시 보니까 좀 잔인하고 불편하고 어두운 영화임.
# 아마도 기가막히는 마무리 땜에 오랫동안  수작으로 생각한 듯 함.
# 암튼 명작인겨겨겨.
# 3.0
# 포스터가 조져놓은 명작이라 칭송받는 범작 아닐까..
# 3.5
#
# 4.0
# 1. 미친 연출력과 미친 연기가 돋보이는 한국에서는 흔히 볼 수 없는 수작.
# 2. 블랙 코미디의 정점
# 3. 지구가 파괴한 사나이가 지구를 지킨다는 아이러니라...
# 3.0
# 나는 이게 병규의 상상이 아니라 정말이었다고 생각할래
# 4.5
# 말도 안되는 얘기를 진짜라고 믿어야만 버틸 수 있었던 남자. 이 미친 세상에서. 그리고 2003년에 이 작품을 세상에 내놓은 장준환 감독 당신은 대체...
# 4.5
# 정말 시간 가는 줄 모르고 본 영화!
# 3.5
# 변종 소재를 이용해 그로테스크함을 그득히 표현한 연출
# 보는내내 안쓰러웠고 클라이막스의 통쾌하지 못한 복수가 이내 아쉬웠던.
# 4.0
# 내가 뭘 본건가.
# B급감성 넘쳐나는데 영화 자체는 A급이었어.
# 3.5
# 결말이 매우 충격적이었던 영화
# 4.5
# 방구석 카타르시스!
# 4.5
# 마지막 ‘그 반전’을 알고 보게 된 영화이지만 영화가 끝나고 가슴이 멍해진다. 영화 속 병구의 대사 “고통이라는 건 절대로 익숙해질 수가 없거든”가 기억에 남는다. 견딜 수 없는 고통과 분노의 대상으로 외계인을 만들어 살아가는 병구. 자신이 그저 미쳐버린게 아니라는 것을 증명하기 위해 처절하게 집착하지 않았을까.
# 4.0
# 짬뽕죽같은... 그래도 보기 잘했다
# 5.0
# 기본을 다지되 독특하게, 멀리서만 찾아왔던 따뜻하고 어두운 어른동화.
# 2.0
# 블랙은 알겠는데 코미디는 모르겠다
# 4.5
# 지금까지 본 sf물 영화중 가장 슬픈 영화였다. 이 영화를 보면서 영화 '조커'와 비슷한 구석이 있다고 느꼈다. 사회적으로 소외받는 존재가 사회에 불만을 표출하게 되는 이야기를 그렸다는 것과 소외된 사회로부터 그가 해방감을 얻기 위해 그의 상상력이 들어갔다는 부분은 조커와 주제가 비슷하다고 할 수 있다.
# .
# 영화를 보면서 감독의 선택에 놀란 것은 전반적인 부분을 B급 장르로 설정한 것이였다. 감독은 이러한 장르를 통해 사회와 단절되어있는 병구의 모습을 잘 나타내주고 상황과 어울리지 않는 유머나 밝은 분위기를 통해 병구의 모습을 더욱 비참하게 보여주기도 한다. 감독은 또한 영화에서 복선을 아주 효과적으로 사용하고 있다. 그는 병구에게 트라우마로 작용되었던 소품들을 병구의 집에 자연스럽게 배치하면서 복선으로 활용하고 있다. 이는 영화의 후반부에 큰 울림을 주게 된다. 초반에 이상하게만 보이던 병구의 모습에 대하여, 무엇이 그를 이 지경까지 만들었는지 이해하게 된다.특히 영화속 병구의 대사 중 '내가 미쳐갈때 어디있었어'는 결국 사회가 철저하게 왕따시킨 사람이 서서히 미쳐가는 과정에서 주변의 도움을 받지 못하는 것이 그 사람을 얼마나 무너뜨리는지를 영화는 시사하고 있다.
# .
# 많은 사람들이 영화속 sf물에 대해 일종의 거부감을 느낄 수 있다. sf적 상상력은 누군가에겐 흐름을 깨면서 말도 안되는 유머라고 생각할 수도 있고, 이런 부분이 영화의 주제를 해친다고도 생각할 수 있다. 나는 이런 의견과 반대되는 생각을 가지고 있는데, 오히려 sf적인 부분이 병구에게 있어 삶의 안식처를 나타내는데 효과적이며 병구만의 삶의 안식처가 사실 마약을 먹여야만 나타날 수 있는 현실에는 없는 부분이라는 점에서 그의 비참함을 더 효과적으로 보여준다고 생각했다. 주인공의 비참함을 두 개의 스토리라인으로 보여준다는 점이 '판의 미로'와도 비슷해 보이는데, 판의 미로와 같이, 두 개의 스토리라인 중 무엇이 사실인가에 대한 포인트 보다 두 스토리라인의 대비를 통해 나오는 병구의 비참함이 더 포인트라고 생각했다. 그가 말도 안되는 외계인 이야기를 끌어올만큼 혹은 약이 아니면 살 수 없을 만큼(약이 아니면 상상도 할 수 없기에) 그는 삶에서 기댈 부분이 없었다는 점을 더 잘 보여주었다고 본다.
# .
# 개인적으로 안타까웠던 부분은 '지구를 지켜라'가 나온 2003년부터 '조커'가 나온 2019년까지 영화가 다루고 있는주제가 변하고 있지 않다는 점이었다. 어쩌면 아주 먼 과거부터 사람들에게 주어진 가장 해결하기 어려운 사회적 문제처럼도 보인다.
# 4.5
# ㄹㅇㅋㅋ
#
# 지하 생활자의 상상 속으로 부터.
# 3.5
# 처음 영화를 보고 마냥 당황했는데
# 다시 생각해보니 의도한 메시지를 제대로 전달하려면
# 이 결말 뿐이겠구나 싶었다.
# 3.5
# 리메이크를 보고 싶다.
# 할리우드가 이때의 신하균을 발견할 수 있을려나
#
# 21.02.13 (22)
# 1.5
# 솔직히 하도 포스터 때문에 과소평가된 영화라길래 기대했더니 실망했다.
# 엽기적인 괴짜 영화...? 조커의 B급 버전?
# 키워드를 알고 봐야 당황하지 않을 듯
# 4.0
# 끝까지 간다!
# 4.0
# 인간이 감당할 수 있는 시련만 주신다면서요...왜그랬어요
# 4.0
# 폭력의 굴레를 벗어나고자 유쾌한 상상을 해본다.
# 4.0
#
# 4.0
# 누가 병구를 이렇게 만들었는가.
# 세상엔 아직 외계인이 많은거 같다.
# 4.5
# 정말 외계인이 있는 걸까,
# 아니면 있다고 믿고싶은 걸까.
# 3.5
# 미치지 않고서 살 수 없는 지독한 삶에서 그려낸 허왕된 꿈이
# 지구를 지켜야 하는 이유가 무엇이었을까
# 권력 앞에 나약한 우리도 히어로가 될 수 있다는 작은 희망이었을까
# 2.5
# 그래도 흥미진진
# 4.0
# 미친 척 하지마 이 미친놈아
# 4.5
# 아.. 이런 인류애 넘치는 휴먼 무비를 이제서야 보다니..
# 3.5
# 진짜 영웅은 언제나 고독하다
# 4.5
# 호기 그 자체의 장르 짬뽕탕 데뷔작에서 혐오는 공감의 바탕 위에서 이해될 수 있다는 어려운 메세지를 소화해낸다
# 3.0
# 저 시절 이 땅은 왜 이리도 야만적이었을까.
# 4.5
# 슬프고 우울하며 반짝인다.
# 2.5
# 결말이 어떻든 시작부터 불리한전제였다. 외계인이 있다 해야지 병구의 광기가 옹호가 되는데, 그렇게되면 너무 뻔한결말로 평가받는다. 그렇다고 외계인이 없다고 한다면 그가해온 만행들이 그저 정신병자의 미친행동으로 남기때문이다. 탄탄한 빌드업 없이 갑작스레 행해진 결말. 근거없는 병구들의 외계인 지식에 의존하여 결말을 설명하기에는 너무 역부족한감이 있다.
# .
# 이동진 평론가의 호평만으로 보게된작품인데 여러부분에서 많이 아쉬움이 남는다. 분명한건 한국에는 없었던 sf코미디 장르이지만. 영화 완성도 측면에서 수작은 절대 아니다. 굉장히 개연성 없는 스토리지만 끊임없는 집중력으로 씬에 몰입한 신하균의 연기가 돋보인다.
# 3.5
# 배우고 감독이고 모두 진지하게 미쳐버린 폭주 장난감 기관차
# 3.0
# 나 역시 실험대상인가..
# 4.0
# 왜 명작이라고들 하는지 알거같은데 모르겠는거 같기도 하고
# 중간중간 한번씩 B급 모먼트 들이 있는데 다 보고 나니까 일부러 그런거 같기도 하고
# 아 포스터 음.... 포스터 진짜 내가 생각해도 보기 싫게 생겼는데 영화 다 보고 나니까 포스터가 다르게 느껴지긴 하네...??
#
# 나 지금 무슨 말 하는거지
#
# 근데 이 영화가 그럼....ㅋㅋㅋㅋ
# 4.0
# "다 안다고?
# 그래, 다 알 수 있겠지.
# 뻔한 얘기니까.
# 근데 다 알면서 어디 있었는데?
# 내가 미쳐 갈 때 어디 있었어?"
# -
# 괴상한 것 같지만 슬픈 블랙 코미디.
# 한국영화에서 다시 나오긴 힘들 독보적인 데뷔작.
# 3.5
# 독특하고 재미있지만 너무 많은 기대를 해서 그런가 생각보다는 평이... 그래도 흡입력은 좋았다
# 4.5
# 한국의 2003 스페이스 오디세이
# 5.0
# 니들의 지구를 지켜라
# 3.0
# 이 때 신하균 너무 예쁘다.
# 4.0
# 결말은 위로의 느낌
# 4.0
# 한국에서 가장 신선하고 상상력이 뛰어난 SF
# 3.5
# 지금 나왔으면 더 흥행 했을듯 한 영화
# 4.5
#
# 2.0
# 재미없고 쓸데 없다.
# 진짜 외계인이면 어쩌고 가짜면 어쩌리.. 결론이 중요한것이 아니다.
# 중간 중간의 설득력과 어떤 추리, 위기 이러한 부분이 부족하다.
# 4.5
# '걱정마 내가 지켜줄게'라고 할 수 없었다.
# 3.0
# 꿈보다는 해석.
# 4.5
#
# 4.5
# 미친놈의 눈을 통과한 현실은 기이하고 슬픈 우화의 세계.
# 근데 사실 우리가 다 미칠 운명이라면?
# 5.0
# 마지막 반전이 어이없었지만 그래서 더 인상깊었다 은근한 비급 연출과 내용, 웃음에 담긴 또다른 뜻깊은 의미가 씁쓸하게 다가와 마지막 엔딩 크레딧까지 모두 보게 만들었음
# 4.0
# 다소 투박하지만 새로운 시도
# 4.5
#
# 3.5
# 이러니까 아리가 좋아하지
# 4.0
# 코미디였다가 드라마였다가
# 종잡을 수 없는 B급영화
# 4.0
# 현실에서 한발자국 떨어진 상상의 세계
# 3.0
# 드라마에 죽고산다
# 2.5
# 글쎄.. 솔직히 난 잘 모르겠다. 다시 보면 좀 다를까?
# 3.5
# 맛있는 쓰레기
# 3.0
# 재미없지도 재미있지도, 다만 평론가들은 좋아할 거 같음.
# 5.0
# 너무 예전에 봤는데 블랙코미디고 뭐고 이거 새드무비 맞죠..? 마지막에 뻥뻥 터질 때 오열한 기억밖에 안난다
# 3.5
# 그래, 너가 옳았어.
# 3.5
# 파격적인 연출, 낭만적인 소재.
# 4.0
# 병구의 서사보다는.. 결말이 좋았다.
# 4.0
# 역시 인간들 노답~
# 4.5
# 정말 내포된 의미가 엄청나다... 사회에 이입해서 생각해보면 정말 많은 생각이 드는
# 3.5
# 나랑 코드가 너무 안맞지만 효과와 편집이 좋은건 알겠다
# 4.0
# 잔인하다
# 2.5
# 어떤 별점을 남겨야 할지 모르겠는 영화
# 3.5
# 신하균과 백윤식의 연기의 합이 너무 좋았다. 특히 신하균의 연기에 다시 한번 반하게 됐고, 그의 섬세한 연기력이 이 영화에 몰입을 할 수 있게 해줬다. 영화를 볼수록 병구가 안타까웠고, 병구를 그렇게 만든 세상과 사람들이 참 나빴다. 이 영화를 보고 두번 놀랐던 포인트는 과거 이야기를 하면서 인간들이 저지르고 있는 잘못들을 비판하는 장면과 마지막 반전의 장면 이었다. 이 영화를 보기 전에 마이너하다, b급 감성이다 라는 평들을 정말 많이 보았는데, 직접 보고 나니 이 영화만의 매력이 분명히 있다. 병구가 없으면 지구는 누가 지키지?
# 4.0
# 모두가 조금씩 돌아버린 세상에서
# 지구가 도는 속도에 어지러워하지 않으려면
# 3.5
# 모로 가도 목적지만 맞으면 된거 아닐까.
# 3.5
# 2020. 11. 01.
# -
# 미친 세상을 살아가려면 미치지 않고서야
# 4.0
# ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ어이없고싶을때 보세용~~~~
# 4.5
# 어디서부터 잘못된 걸까
# 3.5
# 적절한 포스터 만들기도 힘든 영화라 생각.
# 포스터 탓하지 말자
#
# 영화 자체는 스릴넘쳤고 메세지도 분명했다.
# 4.0
# 편하게 볼 수 있는 영화는 아니다. 신선도에 높은 점수. 뭔가 많은 것이 담긴 이야기.
# 4.5
# 다시봐도슬퍼...
# 3.5
#
# 4.5
# 신하균 거의 캐릭터에  빙의한 수준...
# 대사들 찬찬히 뜯어보면 오글거리기 딱 좋은데 연기력  덕분에 하나도 안 어색하다.
# 연출 소품 스토리 어느하나 버릴거없지만
# CJ 투자작 이라 그런지 어쩔수없이 묻어있는 감성이 살짝 아쉽다.
# 4.0
# 병구의 지구엔 뭐가 남아있었을까? 외계인도 포기한 더 이상 희망 없는 행성인데 병구도 마찬가지였지 않나
# 3.5
# 20.10.30.
# 4.0
#
# 3.5
# "저 행성엔 희망이 없어."
# 인류애가 사라질때마다 다들 한번씩 해보는 생각아닌가. 세상에 대한 비판과 환멸감을 영화로 표현했다고 느껴지기도했다.
# 끝날때까지 헷갈렸던 진실. 한국영화 중에 이렇게 신박하고 참신한 영화가 있던가? 진짜 포스터 누가 만들었냐 ㅠㅋㅋㅋ
# 2.5
# 누가 지구좀 지켜봐
# 4.0
#
# 3.0
# 지구를 꼭 지켜야 할까?
# 3.5
# 대박 정신없어
# 3.5
# 나 그래도 영화 보면서 병구 말을 믿고 싶었어
# 4.5
# 분명 초반 나레이션을 들으며 다짐했는데
# 나도 결국 똑같았다
#
# +관객을 고문할 줄 아는 감독...
# 4.0
# 재밌는데?
# 4.5
# 반전있는 결말이지만 결말이 중요한 것이 아니다
# 사회가 다수가 어떻게 개인을 망가트리는지
# 망가진 개인은 어떠한 불행한 결과를 낳는지
# 왜 그랗게밖에 살아갈 수밖에 없는지
# 약자는 왜 강자를 이길 수 없는지
# 결국 피해자는 어떻게 되는지
# 우리는 왜 사랑하는 사람을 지킬 수 없는지
# 4.0
# 정의를 지켜라!
# 3.0
# 영화가 그 당시에는 과소평가를 받았다고 생각한다.
# 영화가 개봉했던 당시였던 초등학생때는
# 김경식아저씨가 해주는 방송에서 보고 정말 보고싶었었다.
# 그리고 결국 미루고 미루다 최근에야 보게됐다.
#
# 다보고 난 후 느낀 점은
# 왜 영화가 그 당시에 과소평가 받았으며
# 왜 지금은 과대평가를 받는다는 느낌을 받는지 알 것 같았다.
#
# 미장센이라든가 주인공의 캐릭터성
# 그리고 반전을 생각하면
# 그 시대를 생각하면 신박한 것은 맞다.
#
# 하지만 오히려 공감하기 어려운 주인공의 사정과
# 마지막에 결국 사실은 이러했다를 긴 장문의 대사와
# 역사스페셜을 보는듯한 연출로 그냥 설명만 하고
# 그리고...
# 마지막 엔딩.
#
# 신박하지만 영화가 비운의 걸작일까하는 생각은
# 잘 모르겠다.
# 4.5
# 미쳐버린 것에 집중하는 것이 좋다.
# 현상이 아니라 본질에.
# 가속성 폭력 유전자.
# 인간은 타인의 슬픔의 본질을 항상 외면한다.
# 자신에게선 슬픔을 찾고
# 타인에게선 기쁨을 찾고.
# 그렇게 자신은 주인공이 되어
# 주변 모두를 불태운 채로 살아간다.
# 대다수의 인간은 언제나 그런 졸작의 영화를 찍는다.
# 나는 어디있었냐고 묻는
# 병구의 말이 기억에 남는다.
# 4.0
# 결말은 실제보다 희극일지도
# 2.5
# 병구를 위한 해피엔딩
# 3.5
# 생각보다 너무 잔인...
# 엔딩이 맘에 든다.
# 4.5
# 사실 백윤식의 고향이 서울인지,
# 안드로메다인지는 별로 중요하지 않다.
# 5.0
#
# 5.0
# K for Vendetta.
# 한국에서 브이 포 벤데타를 만들면 이런 느낌 아닐까.
# 결말을 어쩌다가 TV 돌리면서 봐갖고 좀 덜하긴 했는데 자체가 잘 짜인 영화라 좋았다.
# 흥행 못 했다고 들었는데 이게 왜 흥행을 못 했지?
# 4.5
#
# 4.0
# B급같은데 사실 A급인데 B급
# 3.0
# 이런 이야기를 상상하고 만든 사람은 어떤 사람일까
# + 내가 뭘 봤는지 모르겠다
# 2.5
# 작품은 괜찮으나 시대가 너무 발전해서 영상미가 뒤떨어진다. 그리고 연기 잘하는 사람이 백윤식이랑 신하균밖에 없네. 신박하긴하다.
# 3.0
# 장준환 감독님의 실력은 타 작품을 통해 알고 있지만,
# 이 작품이 정말 대단한지는 사실 아직도 잘 모르겠다.
# 4.0
#
# 4.0
# 시꺼먼 병맛 속으로 진지하게 빨려 들어가는 기분
# 4.5
# 소시민이기에 아무도 믿어주지 않았지
# 특이하고 평범하지 않기에 더 묵살 되어야 했고
# 배운게 미미하기에 보통 사람과 다른 방법을 사용했던
# 주인공 (물파스만 보면.....)
#
# 어쩌면 그 소시민이 지구를 묵묵히 지키고 있는게 아닐까
#
# 고등학교때인가 중학교때 나와서 봤는데...
# 이상하게도 길게 상영하지 않았던 것 같다
# 요새는 개성이란 이름으로 평범하지 않은 것들을 그리 뭐라하지 않은 시절이지만
#
# 당시 학생인 내게는
# 평범하지 않거나 튀면 이상한 아이로 취급을 받아서
# 의미있게 본 영화였다
#
# 이 영화를 보고 신하균님에게 좋은느낌을 받았었다
# 2.0
# 난해하고 독특하고 실험적이다. 눈치 보지 않고 자기가 하고 싶은 거 다 연출해본 듯한 감독 데뷔작.
# 3.5
# 제 5원소 97년도
# 안드로메다 b급 감성
# 3.5
# - 장준환 감독의 독창적인 SF -
#
# <지구를 지켜라!>는 2003년에 개봉한 ‘장준환’ 감독의 데뷔작입니다. 당시 우리나라에서 보기 드문 SF를 소재로 한 영화였죠. 게다가 외계인을 소재로 했습니다. 장르는 SF, 스릴러, 호러 등 다양하게 섞여 있습니다. 코미디 장르도 있지만 영화 속 장면들을 보면 스릴러에 더 적합합니다.
#
# <지구를 지켜라!>는 사실상 한국 SF영화의 출발점을 만들어 주었지만 그 시작부터 기괴한 면을 강조 했습니다. 외계인이라고 확신한 남자를 납치해서 사실대로 말하라고 협박하는데요. 그래서 한다는 고문이 발등을 떼 수건으로 피날 때까지 문지르고 그 위에 물파스를 바르는 장면이나, 다른 외계인과의 교신을 끊기 위해 ‘강만식’의 머리를 밀어버리는 장면 등은 이 영화가 감독의 독창적이면서도 아무나 할 수 없는 상상력이 동원되었다는 점에서, 단순한 코미디가 아닌 기묘한 유머를 담아낸 작품이라고 볼 수 있습니다.
#
# 또한 아이러니하게 웃기게 하고 당혹감을 느끼게 하는 장면도 등장합니다. 영화 중반부에서 ‘병구’를 쓰러뜨린 ‘강만식’은 쓰러져 있는 ‘병구’에게 분풀이하면서 밟아버리는데, 그 순간 그의 발이 ‘병구’의 멈췄던 심장을 다시 뛰게 하는 마사지 역할을 하는 장면이나, ‘병구’가 비장하게 ‘강만식’의 원래 이름(즉 외계인 이름)을 말하려다 몇 마디 못하는 장면, ‘추 형사’가 자신의 집에 찾아오자 관심을 돌리기 위해 밖에 UFO가 있다고 둘러대는 장면 등이 있습니다.
#
# 한편 <지구를 지켜라!>는 사회비판 메시지를 강렬하게 담아내고 있습니다. 주인공 ‘병구’는 불우한 어린 시절을 보냈습니다. 세상은 ‘병구’의 가족들과 그의 여자 친구를 지켜주지 못했고, 그는 피폐해진 삶을 살아갑니다. 결국 외롭게 컸던 ‘병구’가 자신의 울분을 토할 수 있는 것은 외계인을 붙잡아다가 고문하는 길로 이어집니다. 사람들은 ‘병구’가 정신 나갔다고 생각하지만 사실 ‘병구’는 세상을 향한 불만을 표출하는 나름의 방법을 고안해내고 있었던 것입니다.
#
# - 흥행에 실패한 비운의 데뷔작 -
#
# <지구를 지켜라!>는 개봉 당시 여러 시상식에서 신인감독상을 비롯해 많은 상을 수상했을 정도로 전문가들에게 높은 평가를 받았었는데요. 하지만 수상실적과는 별개로 흥행에는 실패했습니다. 전국 관객 수는 고작 7만 명으로 손익분기점에도 못 미치는 초라한 성적을 거뒀습니다. 청소년관람불가 등급임에도 단순한 코미디 영화라고 생각했던 관객들은 영화를 보고 나서 꽤 당혹스러워 했을 것 같습니다. 물론 이 영화를 좋아하는 분들도 있긴 했지만 결과적으로는 실패했습니다. 실험영화 성격을 가지고 있어서 그런 걸 수도 있지만 참으로 아쉬운 결과였습니다.
#
# 많은 사람들은 <지구를 지켜라!>가 실패한 이유를 마케팅을 잘못해서 그렇다는 의견이 많습니다. 영화 포스터만 봐도 작품자체가 코미디 영화라고 홍보하는 느낌이 들었고 예고편도 영화의 분위기와 동떨어진 재밌을 것만 같은 작품임을 유도해서 더욱 그렇게 느껴지네요. 이와 같이 비슷한 사례로 흥행 실패한 작품으로는 <김씨 표류기>(2009)가 떠오릅니다.
#
# 어쨌든 그 이후 영화 활동을 거의 하지 않았던 ‘장준환’ 감독은 그 사이 배우 ‘문소리’와 결혼합니다. 그리고 <지구를 지켜라!> 이후 10년 만에 <화이: 괴물을 삼킨 아이>(2013)로 복귀했고, 그 후에는 <1987>(2017)로 흥행에 성공하면서 재기에 성공합니다.
#
# 최근에 본인의 데뷔작 <지구를 지켜라!>의 영어 버전 리메이크 영화의 감독을 맡게 되었습니다. 제작은 <유전>(2018), <미드소마>(2019)의 감독인 ‘아리 애스터’입니다. ‘아리 애스터’ 감독은 평소에도 한국 영화에 대한 지대한 관심을 보였고, 특히 <미드소마>의 영향을 준 작품 중 <지구를 지켜라!>가 있었다고 합니다. 본인의 저주받은 걸작을 해외 버전에서 어떻게 살릴지 기대가 됩니다.
# 4.0
# 홀로 지구를 지키는 괴짜 히어로
# 4.0
# 지구엔 악인이 너무도 많아
# 5.0
# 외계의 경계 위에서
# 3.5
# 미친건 내가 아니라
# 1.0
# 네이버 평점을 안믿기로 했다
# 3.5
# 2020.09.05
# 집
# 4.0
# 상상력이 대단
# 3.5
# 내가 봤던 한국 영화중에 신박한 걸로 따지면 1등일 듯
# 5.0
# 병구 과거 회상할 때 너무 마음이 아팠음
# 4.0
# 지구를 지키지 못하면 살 수 없다
# 우리는 대부분 그런 인생을 살고 있으면서 병구처럼 근본적인 원인에 맞서지 않고 있다
# 3.0
# 진짜는 둘. 병구는 외계인을 이용해 사리사욕 채운건 아닌가.
# 4.0
# 나의 지구를 폭파시켜줘
# 4.5
# SNSD - I got a boy
# 2.0
# 20200825
# 나랑은 안맞는듯 하여 한시간보다가 종료를 하였다
# 4.5
# 시대를 앞서간 걸작. 아직 이 영화를 인정할 시대는 오지 않았다.
# 4.0
# 임팩트는 참 좋은데 뭐라 설명을 못하겠네
# 5.0
# 주어진 환경을 원망하며
# 분노 해야할까 아니면
# 이겨내야 할까
# 누가 봐도 후자가 답이라 할수 있지만
# 그 답을 행하긴 너무도 힘들다.
# 4.0
# 이 행성은 답이없어
# 4.5
# 재미따. 그런 기분일때가 있잖아요 그냥 믿고싶을때.
# 캐스팅 미쳤다. 백윤식 어쩜...
# 4.0
# 결말이 말도 안 되게 좋다🌏
# 2.5
# 나는 ... 잔인한 걸 너무 못보겠어ㅠㅠ
# 4.0
# 머리가 띵하넹
# 4.0
# 3.8
# 4.5
# 포스터 누가 만들었냐 진짜 재평가 시급
# 3.5
# 발차기 심폐소생술에서부터 이 영화에 반해버렸다.
# 4.0
# 재미있게 본 사람을 깔 필요도
# 재미없게 본 사람을 깔 필요도 없다.
#
# 인간을 사랑합시다.
# 2.5
# 거품
# 4.0
# 원죄는 유전자 조작.
# 구원을 위해 내려온 신은 악덕 기업 사장.
# 소외받은 자들이 존재하는 이유는 그제서야 설명된다.
# 3.5
# 정말 과감하고 독특한 영화. 블랙 코미디같은 면도 갖고 있으면서 스릴러의 특징을 띄고 있어 인상적이였다. 주인공의 상상과 신념이 결말에서 이루어질 때의 쾌감. 시대를 앞서간 비운의 작품이 아닌가 싶다.
# 4.0
# 미친놈아! 미친척 좀 그만해!
# 4.0
# 명작
# 2.0
#
# 보고싶어요
# From the Indiewire article about “Midsommar”.
# One reason “Midsommar” is able to sustain a drug trip for so long is because the psychedelia is propped up by a story that’s doing a number of other things at the same time. Aster, like many of the filmmakers he loves, has a gift for compounding different genres together in a way that blurs the lines between them. It’s why he’s always been quick to mention contemporary South Korean cinema as an inspiration, and why some of the pivotal moments in “Midsommar” feel like they’re picking up where the last act of Park Chan-wook’s “Lady Vengeance” left off, or playing with some of the same dynamics that Jang Cheol-soo explored in “Bedevilled” (a more obscure reference that Aster remembers well).
# “There are so many South Korean films that have come out in the last 20 years that have just made me feel like…” Aster smiled and shook his head. “I love how they juggle different tones. Lee Chang-dong, Bong Joon-ho, all the usual guys.”
# Asked to pick one movie in particular that he felt in his bones and that may have given him permission to shoot for the moon with the gonzo finale of “Midsommar,” Aster cited Jang Joon-hwan’s deliriously unclassifiable “Save the Green Planet!,” which starts with a deranged man kidnapping a rich pharmaceutical executive who he’s convinced is a hostile alien, and only gets stranger from there. “That was a huge thing for me,” he said.
# 3.5
#
# 3.5
# 스토리도 충격적이지만 디테일한 미장센은 압도적이다. 비주얼 쇼크
# 5.0
# 티비 속 병구의 행복한 웃음들이 자꾸 생각난다.
# 2.5
# 끝을 제대로만 냈어도 삼류 안 같았을 듯 흥미롭고 역작일 수 있었는데 마지막 끝이 너무 비급
# 2.5
# 진짜 외계인이라는 점이 말하고자 하는 걸 애매하게 느끼도록 만든 것 같다.
# 2.5
# 억지스럽게도 뻔뻔하네..
# 4.0
# 최고다..
# 3.5
# 이게 정말 다 외계인의 계략이었어야 말이 되는 미친 세상에 대한 고발
# 4.5
# 지구를 지키기 위한 병규의 피나는 노력
# 5.0
# 이건 5점도 아깝다.
# 이 돈에 이렇게 뽑기가 쉬운 게 아니라고~
# 4.0
# 아빠가 보고 또라이 같은 영화라고 했는데 맞는듯
# 웰메이드 그로테스크 끝판왕
# 3.5
# 쭉 괴랄하다가 마지막 10분으로 수작이 됨
# 3.0
# 시대를 너무 앞서간 작품.
# 2.0
# 아리에스터 리메이크 버전 얼른 내놔요
# 2.5
# 명작이라는 말에 홀려서 이게 뭐야 궁금해서 계속보게 되는 괴기스런 필름
# 4.5
# 병구가 사랑했던 모든게 파괴된 그 현실이 족같은 외계인 새끼 때문이라 다행이다
# 4.5
# 그저 미쳤다고 밖에 할 말이 없다. 지구인도, 외계인도, 영화도.
# 3.0
#
# 4.0
# 차라리 정말로 그들이 외계인이었더라면.....
# 5.0
#
# 5.0
#
# 4.5
# 이 영화를 본 후의 감상이  " 그래 병구가 옳았어!"가 되면 안될 것이다.
#
# 분노의 끝은 어디로 가는가?
# 병구는 지구를 지키기 위해서 사람들을 납치하고 이들이 외계인일 거라고 굳게 믿는다. 실제로 정말 그렇게 믿고 있다.
# 하지만 사장이 모든 것을 고백하고 자신이 외계인임을 고백할 때 병구는 "거짓말,  더이상 속지 않는다"고 말한다. 왜냐햐면 자신의 분노의 종착지가 보이는 것이 두렵기 때문이다.
#
# 사장이 정말 외계인이라면,  그래서 교신에 성공한다면 이제 병구는 무엇을 해야 할까?
# 분노가 수단이 아닌 목표 그 자체가 될 때 최후에 개인에게 남는 것은 잿더미 뿐이다. 누구도 스스로를 태워 재가 된 채로 나 없는 세상을 밝히고 싶어하지 않는다. 하지만 선택지가 그것밖에 없을 때, 억압과 분노가 담론을 만들지 못하고, 동료를 만들지 못하고, 이 모든 것들의 원인이자 결과가 개인에게 부과될 때 개인이 할 수 있는 유일한 선택은 스스로를 불태우는 것 뿐이다.
#
# 모두가 모이면 한 사람이 촛 불 하나만 밝혀도 그것은 거대한 등불이 된다.
# 하지만 혼자서 그 불을 만드려면 자신의 몸을 태워야 한다.
#
# 분노에 정당성이 없다는 말이 아니다. 분노하지 말아야 한 다는 말도 아니다.
# 분노는 차별과 억압의 인식 뒤에 오는, 더는 그것을 정당화하지 않는 더 나은 세계를 만들기 위한 길의 중요한 과정 중 하나다. 하지만 행복해지기 위해서
# 분노를 결과가 아닌 나의 과정으로 삼아야 한다. 다른 누구도 아니라 나를 위해서.
#
# 하지만 분노를 과정으로 삼는 일은 나 스스로가 원한다고 할 수 있는 일이 아니다.
# 내가 겪은 부당한 일들이 나만 겪는 일, 나만의 일이 될 때 어떠한 사람도 이 분노를 다스릴 수 없다. 왜냐하면 너무 억울하기 때문이다. 정말로 억울한데 왜 억울한지, 왜 분노할 수 밖에 없는지를  세상의 언어로 말 할 수 없기 때문이다. 세상이 인정조차 하지 않기 때문이다.
#
# 더 나아가서 세상은 내가 분노하고 있다는 사실 조차 알지 못하기 때문이다.
#
# 세상이 나에게 "네탓이오 네탓이오 다 너의 탓이다, 너의 분노는 네가 원인이다"라고 말 할 때  개인은 스스로를 불태워 분노를 보여준다.
# 그래서 사회적 인식이 필요한 것이다. 나와 같은 분노를 같이 겪은 다른 사람들을 만날때, 내가 왜 이렇게 화가 났는지 이야기 할 수 있는 장이 있을 때, 더 나아가 분노하여 지껄이는 나의 말을 세상이 귀기울여 들을 때 비로소 개인은 분노를 하나의 과정으로 인식하고 다음 단계로 나아갈 수 있다.
#
# 여기까지 감상을 읽고 '그래, 병구는 세상의 순결한 피해자야 세상이 잘 못했지' 라고 생각한다면 나의 글을 오독한 것이다. 감독이 어떤 생각을 가지고 있는지는 내가 모른다. 그러나 이 영화를 본 나의 감상은 이렇다는 거다.
#
# 우리는 모두 다면적인데다 세상과 다양한 방식으로 연결되어 있어서 나는 피해자인 동시에 가해자가 될 수 있다. 분노는 더 큰 분노를 부른다. 가스레인지의 불은 일용할 양식을 만들지만 캠핑장에서 잘못 튄 불씨는 산을 태운다.
#
# 분노하는 것은 매우 매력적이다. 분노를 목표삼아 더 광대한 분노를 만들어내는 것은 거의 중독적이다. 그 때의 전율은 마약과 같다. 한 가지 일을 너무 오랫동안 끊임없이 하다보면 우리는 그 일을 왜 시작했는지를 잊어버리곤 한다. 나를 보이고 싶어서 불을 질렀는데 기억의 망각 속에 우리는 불내는 것 자체를 목적으로 생각할 때가 있다.
#
# 세상은 개인이 구조에서 받는 불만을 적극적으로 듣는 사회를 만들기 위해서 노력해야 한다. 개인은 분노를 수단으로 사용하는 방법을 알아야 한다.
#
# 이 사회에 분노한다며 칼을 들고 아무나 푹 찔러 버리는 사람을 제 3자의 입장에서 보자. 세상이 정말 그에게 부당한 일을 했는가? 들여다보면 yes일 수 있고 no일 수 있다. 일단 그렇다고 가정하자. 그렇다면 세상의 부당함을 알리기 위해서 아무나 찔러 죽인 이 사람은 사회의 피해자인가? 아니면 개인의 가해자인가?
#
# 정답은 둘 다다. 이 사람은 피해자이자 가해자이다.
# 병구는 피해자인가 가해자인가? 병구는 피해자이자 가해자다. 병구의 피해사실이 가해에 영향을 준 것은 분명하지만, 그는 안타까운 사실이지만 살인자의 정체성도 병구라는 사람을 이루는 다양한 면들 중 하나임을 알아야 한다.
#
# 그렇다면 정당방위는 없는 것인가? 하고 누군가 물을 수 있겠다.
# 그래서 우리는 결과만을 볼 게 아니라 과정을 유심히 들여다봐야 한다. 이건 어떤 가해자에게 서사를 부여해서 죄를 경감시켜주자는 말이 아니다. 또한 정말로 정상참작이 가능한 부분을 무시해버리자는 게 아니다.
# 인과관계를 잘 살피고 피해와 가해가 어떤 관계를 맺고 있는지, 인과관계를 맺고 있는지, 그 안에서 왜곡되거나 비약된 부분은 없는지 진중하고도 자세하게 들여다봐야 한다는 말이다.
#
# 세상의 모든 것이 옳고 그름으로 나뉜다면 세상살이는 훨씬 더 편해질 테지만 안타깝게도 이 땅의 모든 것은 그렇게 작동하지 않는다. 모든 것은 스펙트럼이며 정도의 차이이며 조절의 차이이다.
#
# (사실 글을 쓰면서도 스스로 확실히 말하지 못하는 부분이 있었다. 하지만 마음속에 담아둔다면 지금의 감상은 휘발되 버리기 때문에 정확히 들어맞는 단어와 문장을 고르지 못한 지금이지만 내가 알고 있는 다른 단어들을 어떻게든 끌어 모아서 내가 느끼고 있는 모호한 감정을 -대충 -비슷하게 그려낸 감상을 써냈다.
#
# 어쩌면-이 아니라 확실히 - 시간이 지나면 나의 감상은 달라질 것이다. 생각도 바뀌겠지. 오랜시간이 지났는데 내가 이 때와 똑같이 생각한다면 더 문제다. 생각이 전혀 진화하지 못했다는 뜻이니까.)
# 3.0
# 20. 6월
# 5.0
# 미쳐가는 삶. 미친 표현. 미친 영화.
# 3.0
# 기대를 너무 많이 했다 기묘하다 기묘해
# 미드소마에 영향을 줬다는데 무슨말인지 너무 잘 알겠고요...
# 그래도 전무후무한 한국영화인거같다
# 2.5
# 2004년에 만들어진 SF 영화라 기대한건데.
# 2.5
# A급 취급받는 B급
# 4.5
# 와 대박이다
# 1.5
# 신하균 젊은 시절 훔쳐보기 그 이상 그 이하도 아님 너무 징그럽고 괴로웠음... 난 모르겠다..
# 4.5
# 데뷔작이었기에 가능한 통쾌한 위트.
# 2.5
# 2020년 6월 22일 월요일 봄.
# 3.5
# 진짜 미친 영화네 ㅋㅋㅋㅋㅋ
# 3.5
# 재미는 있지만 끝나고 기분이 너무 나쁘다
# 3.0
# 기대하고 봤지만 글쎄,,?
# 3.5
# 기대거나 기대할 곳 없는 지구를 어떻게든 지켜보려는 일부 지구인에 대한 헌사
# 4.0
# 포스터 제작자는 영화를 안 본 게 틀림없다
# 3.5
# 병구는 누가 지켜주지?ㅜㅠㅜㅠㅠㅠ
# 3.0
# 이 행성은 희망이 없다.
# 3.0
# 다크 초콜릿처럼 썩 달지 않고 쓰디 쓴 그 시절의 블랙 코미디
# 4.0
# 그래 .. 인류는 종말뿐이다...
# 3.5
# B급영화를 가장한 A급영화
# 4.0
# 이제  지구는 누가 지키지...?
# 3.5
# 뭐라고 해야 할 지 모르겟어요
# 4.5
# 여러모로 놀랍다. 잔인하기도, 적나라하기도 한 그시절 sf
# 4.5
# 고통은, 유전자 결합구조를 약하게 만들어
# 그래서 가장 고통을 많이 받는 사람이,
# 가장 쉽게 변할수 있어
# 5.0
# 이게 이렇게 눈물나는 영화였단 말인가
# 4.5
# 대한민국 뿐만 아니라 전세계 영화사 중 제일 창의적인 영화가 아닐까!
# 5.0
#
# 4.5
# 최고의 결말. 처음 봤을 당시 충격이  어마해서 다시 찾아봄. 가장 고통받은 사람이 가장 변화하기 쉽다. 최고의  SF  범죄 스릴러 휴먼  드라마 영화.
# 2003년 살인의 추억, 올드보이와 같은 선상에서 재평가 되어야할 영화.
# 2.5
# 몇 점을 메겨야 할지 혼란스럽다.
# 2.5
# 과소평가됐대서 봤는데....ㅠ 비슷한 평인 김씨표류기도 믿고 걸러야되겠다...
# 2.0
# 내용이해에 실패했다
# 5.0
# 썩은 자본주의와 발버둥치는 노동자. 외계인과 지구수호자란 기발하고 재치있는 발상으로 풀어냈다. 편집이 인상깊었다. 잔인할 것 같아서 시나리오로 먼저 읽었었는데 시나리오나 영화나 좋았다
# 4.0
# 진정한 매드맥스
# 3.5
# 난 B급 영화들이 좋더라
# 3.0
# 굳이 경찰들 이야기를 넣어야했을까?
# 4.0
# B급 CG에 B급 감성 영화인 줄 알았으나..뒤로 갈수록 집중하고 있는 나를 발견한다 대체 포스터를 왜 저렇게 뽑았는지 아직도 의문이고..암튼 재밌었음
# 4.0
# 포스터 누가 만들었냐
# 5.0
# 날 신하균의 세계로 내던져준! 영화
# 내 인생은 이 영화 이전과 이후로 나뉜다
# (인생 처음으로 구매했던 DVD도 이것)
# 3.0
# 병구에겐 존윅같은 면이 있었을는지도. (지분은 낮지만 귀요미 꼬질이 지구♡)
# - 섬세하게 미쳐버린 연기를 너무나도 잘 해버린 신하균과, 백윤식의 비굴하고도 어딘가 자만심 넘치는 캐릭터라. 영화내용은 나랑 안맞아도 둘의 연기구도는 가히 대단하다.
# - 다만 순이 역의 황정민이 그런 역할이어서 짜증이 나는건 어쩔 수 없는가.
# 5.0
# 처음. 병구에 대한 믿음
# 중간. 만식에 대한 믿음
# 마지막. 만식을 믿었던 것에 대한 후회
# 3.0
# B급 최대 아웃풋
# 3.5
# 내가 이렇게 죽으면 지구는 누가 지키나, 말하는 쌈마이 SF의 블랙 코미디.
# 3.5
# 지구를 부숴라!
# 1.5
# 과소평가돼서 과대평가된 듯
# 나랑 비슷한 생각을 하는 평이 많아 신기했다
# 5.0
# 우리는 이것을 그저 유니크한 컬트영화로 봐야하는 것이 아니라, 사실 21세기형 계급투쟁영화로 보아야한다.
# 4.5
#
# 4.0
# 잘못하면 성냥팔이 소녀의 재림처럼 실험적인 척하는 b급이 되었을 듯.. 나는 오히려 엔딩의 병맛함이 관전자로서의 죄책감을 줄여주는 것 같아서 좋았다. 부디 죽은 뒤에는 스스로 원하는대로 이루어지길
# 3.5
# 상징들이재밌었다
# 4.0
# 웃음으로 다가와 강력한 페이소스를 남기고 떠나는 외계인같은 영화.
# 5.0
# 천재 아님??
# 3.0
#
# 3.5
# 정신이 왹져진다...
# 4.0
# 불호를 호하는 나. 내 취향이다.
# 4.5
#
# 4.0
# 지구야 미안해
# 5.0
# 리메이크작에서 원작 이상의 엔딩을 창조한 순간부터 아리 애스터와 장준환은 전설이 될 것이다
# 4.0
# 범작을 넘어서 명작으로 가는길
# 4.0
# 13년동안 스포당하지 않은 나 자신에게 토닥토닥...
# 4.0
# 유쾌하지 않은 상상력
# 4.0
# 인류에 대한 고찰
# 2.5
# 인터넷에서 과대평가된 영화중 하나
# 4.5
# 주인공의 처절함과
# 안타까운 사연으로
# 감동을 받고 있었는데
# 마지막에서 급발진에
# 핸들을 반대쪽으로
# 확 꺾어서 적잖이
# 당황스러웠다
# 3.5
# 진지하기에는 웃기고
# 마냥 웃기엔 불편한 영화였네요
#
# 만화 속에서 영웅은 결국 승리하지만
# 현실 속 영웅은 아무도 모르게 죽어가나봅니다
# 4.0
# 왜 장준환이 천재인지도, 왜 흥행에 참패했는지도 납득이 되는 영화. 서스펜스가 터지면서 진행되는 후반부에 비해서 중간에 루즈해지는 부분이 아쉽지만 이 정도 창의력에 상상력이면 사람은 안 많아도 별점은 줄 수 있잖아! 뻔한 남성 감독으로 자랄 뻔했던 봉준호와 장준환을 지켜주신 그 무엇에도 감사드립니다. 지구를 지켜주소서 하는 존재가 병구에서 메기로 옮겨간 2003과 2018 그 간극까지 톺아보는 맛은 결국 그 시선이 따라가는 하부에서 온다.
#
# + 동생은 재밌긴 한데 영화관에서 봤으면 좀 짜증났을 것 같긴 하다고 함ㅋㅋ
# 4.0
# 누가 병구를 파괴했을까.
# 2.0
# 이걸 내가 그때 봤었다면 더 좋게 볼 수 있었을까? 명작이라고 한 새퀴들 다나와
# 4.0
# 풍요롭던 충무로 시대의 다양성과 작품성의 극한.
# 2.5
# 하도 과소평가됐다고해서 아껴둔 영화. 기대에 부푼마음으로 젊은 하균신님을 만났는데...세상에나 ㅇㅅㅇㅋㅋㅋ어느순간 한껏 미간을 찌푸리고있었다. 보는내내 배우들에게 감탄함. 이런 대본을 이렇게 소화한다고??!! 얼탱방탱한 대사와 상황들을 핵진지하게 연기하는것을 보니 헛웃음이 날 정도. 스토리는 별로 설득력없었지만 연기력하나는 리얼 인정.
# 4.0
# 이런 미친..
# 4.0
# 신박하고 신박하고 신박하다
# 4.0
# b급인 척 하는 a급 영화
# 5.0
# 장르: 코미디, 드라마, 로맨스, SF, 액션,  스릴러, 미스테리
# 5.0
# 놀라운 성취. 패기 넘치는 출발.
# 1.5
# 지구가 끝장 나는 날>지구를 지켜라
# 4.0
# 이제...지구는 누가 지켜?
# 4.0
# 편협한 시선을 완전히 비꼬아 버리는 후반부
# 4.0
# 우리는 오늘도 지구를 지키지 못한 것 같다.
# 4.5
# 데뷔작이 이 정도일 수가 있다니. 선을 아는 창작자의 가차없음에 반하고, b급으로 빠질 수 있는 소재를 솜씨좋게 다듬어냄에 반한다. 무엇보다도 너무 재밌다. 200408
# 4.0
# 믿기지도 않는 걸 점점 믿고 싶어진다.
# 이쯤 차고 넘칠만큼 고혹적이다.
# 4.0
# 코믹으로 알고 봤다간 큰코다친다.
# 3.5
#
# 3.5
# 솔직히 초반에는 이게 왜 명작이라는거지..? 싶었다.
# 하도 포스터 때문에 사람들이 나온 당시에 안봤다고 유명했기 때문이다. 근데 점점 갈수록 재밌어졌다.
# 특히 강사장이 분명히 병구의 일기? 를 봤을땐 슬퍼하길래 드디어 죄를 깨달은건가 싶다가도 또 병구를 죽이려들길래 아니뭐여 싶었는데 마지막 장면을 보고 모든게 이해가 가면서 이 영화가 좋아졌다.
# -2020.04.04
# 1.0
# '과소평가돼서 과대평가된 영화' 호평에 속았다
# 3.5
# 미친영화다
# 4.0
# "이제 지구는 누가 지키지?"
# 4.0
# 몇십년 만에 다시 봤는데 놀랄정도로 세련되고 잘 만든 영화다. 감독이 누군가했더니 아 장준환...어떻게 이런 데뷔작을! 처음 볼 때도 반전을 알고 봐서 넘 아쉬었는데  지금 보니 -반전을 알고 있는게 아쉽지만서도- 그 이외의 것들이 정말 잘 만들어진 영화다. 신하균의 선하면서 서늘한 연기, 끝까지 의심을 풀 수 없는 이야기,  촘촘한 구성, 잘 짜인 구성....장준환은 과소평가 되는 감독 중 하나가 일까 싶다. '내가 이렇게 될 때 너희들은 뭐했어? 너희가 더 나빠'
# 4.0
# 백윤식
# 연기에 감탄
# 오랜만에 좋은 B급
# 2.5
# 지구를 위한다는 마음만 받겠습니다....
# 2.5
# 저 지랄할 줄 알았다
# 4.0
#
# 3.0
# 니들은 날 못 이기고 강사장님은 먼저 모시는 곳 = 지구
# + 50대 선생님 근육을 본받자
# 2.5
# 내가 본 영화중에 제일 병맛이다 와
# 4.0
# 시대를 앞서간 영화. 한국 영화에 이런 영화가 존재했다라는걸 이제 알게되었다. 쿠엔틴 타란티노 느낌이라고 할까.
# 2.0
# 좀 징그러움
# 4.5
# 차라리 농담이 진짜이길 바라는 마음
# 1.5
# 한국적 SF...? 저평가된 명작...? SERIOUSLY....?;;;
# 아리에스터가 영감받은 작품이라해서 내심 기대했는데, 재밌지도 신선하지도 놀랍지도 않았다. 2003년 개봉작이라는 걸 굳이 감안해주고 싶지 않다.
# 2.0
# 완벽한 코리안 블랙 코미디
# 4.0
# 병구는 그저 자신이 사랑하는 것에 충실했을 뿐
# 4.0
# 띠이이요오옹ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ
# 3.5
# 장르가 틀렸다.
# 스릴러 / 코미디 가 아니라
# 휴먼 / 스릴러 가 되어야 맞다.
# 나 이거 보다 울었거든
# 4.5
# 왜 상업적으로 처참하게 망했는지 단박에 알 수 있는 코미디영화. 말장난 같지만, "과소평가 받았다고 과대평가 받는다"고 과소평가 받는 느낌.
# 4.0
# 사회 로부터 버려지지 않기위해 바지자락을 물고 늘어지며 발악하는 편집증 환자의 스토리
# 5.0
# 딱 한 사람, 딱한 사람
# 4.5
# 우리나라에서 이런 영화도 좀 더 나와야 하는데
# 많은 의미로 씁쓸한 영화
# 5.0
# 병맛이 아닌 별맛
# 3.0
# B급 영화라지만 조금만 세련되게 만들었어도 지금 봐도 오글거리지 않았을 텐데... 독특하지만 촌스럽다
# 1.5
# 네???
# 3.5
# 반전이 반전이 아니다. 외계인이 아니면 말이 안되니까
# 3.0
#
# 5.0
# 영화적으로 완벽한 영화를 꼽으라고 했을때, 예시로 들 수 있는 영화 중 하나.
# 4.5
# 스릴러? 코미디? 장르는 말 그대로 장르일뿐, 설정 또한 큰 그림을 그릴 설정일뿐 희대의 역작이다
# 어설픈 CG, B급 감성조차 숨죽여 볼 수 있었던 유일한 작품
# 인간들아 지구 좀 지키자
# 4.0
# 망상 속에 살아가는 소외된 인간이 만들어내는 환상의 세계
# 3.5
# 과소평가 받았다는 이유로 너무나도 과대평가 받은 영화.
# 3.0
# 왜 포스터 탓만 해요
# 3.0
# 익살스러운 모습으로 전달하려는 영화의 메세지.
# 5.0
# 누가 뭐래도
# 내인생 최고의 오락 영화
# 병구와 지구 모두 행복했으면
# 1.0
# 포기
# 4.0
# 충격적인 작품. 더 좋은 그래픽 기술과 연출 방식이 뒷받침됐더라면 어땠을까.
# 4.0
# 너무 잔인해서 다른 코멘트가 생각이 안나,,
# 4.0
# 같은 인간이 저지른게 믿겨지지 않은 행동들. 차라리 그들이 외계인이길 바래본다.
# 4.5
# b급영화는 b급이 아니다 장르일 뿐이지
# 2.0
# 아찔한, 앞지른 상상력 충무로의 외연을 넓히다
# 4.0
# 고통이라는 건 절대로 익숙해질 수가 없그든...
# 4.0
# 매니아들에게는 걸작으로 꼽히는 작품이다.
# 3.5
# 2020.2.15 뭐라고 해야할지 모를 모든 처참함을 가진 지구용사.
# 4.0
# 이런 작품들 덕분에
# 한국영화계가 지켜지고있다
# 5.0
# 난 이 작품을 평가할 자격이 없다
# 4.0
#
# 1.5
# 난잡해도 너무 난잡함
# 3.5
# 평점이 몇점이든 납득이 가는 영화
# 4.0
#
# 3.0
# 블랙코미디라는 건 인정 그러나 스릴러, SF로는 함량미달
# 3.0
#
# 4.0
# 지키지 못한게 많아 처절하다
# 3.0
# 도저히 제정신으로 살 수 없던 병구에게는 외계인이라는 존재가 있어야만 했다. 사람이 의지할 곳이 없으면 신적인 영역이나 믿기 힘든 것에 빠지기 쉽다는 걸 새삼 또 느꼈다. 이제 지구는 누가 지키나...
# 그리고 신하균 연기 진짜 잘한다!
# 3.0
# 내가 뭘 본거여...
# 3.5
# 보면서도 헷갈렸던 영화. 이런 내용인지 모르고 봐서 당황스러웠음.
# 5.0
# B급을 흉내내는 슈퍼초울트라S급 한국영화
#
# 감독 데뷔작이라는게 두번놀람
# 2.0
# 내가 이 영화에 호감일 확률이 얼마인지 알아? 0 퍼센트야. 불호이거나, 불호거나. 단순하게 생각하라고. 확률은 반반이 아니니까.
# 3.0
# 포스터 네이놈!
# 4.5
# 홍보미스의 대표적 예시
# 4.5
# 미친놈 덕에 즐겁게 봤다
# 4.0
# B급 정서 코미디 영화에서 보기 힘든 충격이다. 병구의 모습에서 보여주는 병든지구의 현실
# 20.01.28 태왕리더스
# 2.0
# 뭔 말인진 알겠는데...
# 참 취향타는 소재, 귀 아픈 러닝 타임
# 4.0
# 이거 보여준 사람도 이 영화만틈 이상하고 B급이었는데
# 3.5
# 2020년 배우들에 젊은 얼굴에 놀람
# 신선도에 놀람
# 자극적임에 놀람
# 1.0
# 누가 띵작이래
# 3.0
# 잘 만든 데뷔작
# 하지만 이 영화를 보고 나는 신하균과 한 걸음 더 멀어졌다
#
# +정말... 감독님은 어떤 사람일까.?
# 3.5
#
# 3.0
# 뭐야 미친 무서워...
# 4.0
# 내  무너진 지구를 어떻게든 세우려는 몸부림
# 4.5
# 도무지 이해할 수 없는 것을 어떻게든 설명해야만 하는 슬픔
# 4.5
# 웃기고 기묘하고 씁쓸하고 기괴하다
# 과장된 연기랑 목소리 톤이 오히려 재밌었음 킬링타임용 b급처럼 생겨서는 가볍게 보긴 좀 힘든 감이 있는데 심각해질때쯤 기묘해지기를 반복ㅋㅋㅋㅋ 아리 애스터 감독이 영향 받은 영화 중 하나라고 들어서 어떤 기묘한 영화일까 했는데 재밌다 계급풍자보다는(전형적인 암청색 남자가득영화st라 그런지 촌스러운 면이 있어서) 전체적인 광기가 마음에 든다
# 4.0
# 지구멸망 기원🙏🏽
# 3.5
# sf같은 복수극
# 3.0
# 마케팅팀이 망쳐버린 명작
# 4.0
# 항상 그래왔어
# 이 삶을 버티게 하는 것도, 사랑
# 살아날 용기가 생기게 하는 것도, 사랑
# 누군가에게 존재의 이유일지도 모르는 사랑을 방해하는 건 분명 사람이 아닌 외계인일꺼야
# 1.0
#
# 2.0
# 과소평가? 재평가? 글쎄...
# b급감성으로 만들었다고 b급 기준으로 감상할 수 없다. 최근 자주 나오는 칭찬받는 b급 감성 작품들은 b급의 탈을 쓴 a급이라서 그런거지, 이 영화처럼 그냥 겉과 속 모두 b급이라서가 아니다.
# 많은 이들이 상상력+메세지 에다가 애초에 b급이란걸 이유로 고평가 해주려는거 같다. 마치 게이머들이 대작 게임은 뭐 하나만 맘에 안 들어도 별점테러를 날리면서, 인디게임은 평타만 쳐도 별점 꽉꽉 채워주듯이 말이다.
# 특히 기껏 고심해서 만든 이 영화 최대 장치도 유주얼 서스펙트를 대놓고 따라한 것뿐이라 맘에 안 든다.
# 그리고 스토리에 대해 진지하게 말해보자면, 안드로메다 왕자 역시 갑질을 일삼고 폭력적인 모습을 보여주는걸 보면 인류의 폭력적인 유전자는 유전자 실험 때문이 아니다. 그 시작부터 폭력적이었으며 안드로메다 놈들도 똑같다.
# 4.0
# 이제 지구는 누가 지키지?
# 3.0
# "다안다고..? 다알겠지.. 뻔한 얘기니까.. 근데 다알면서 니들은어딨었어.. 내가미쳐갈때 니들은 어디있었는데.. 니들이더나빠.. 니들이죽인거야.. 니들이다죽였어"
# 3.0
# 보다가 그만두고 다시본 작품. 보다 그만둔 이유가 있었던거 같다. 내가 기대를 너무 크게 한걸까 생각보다 그저그랬다. 그래도 B급 감성으로 이정도 만든거면 잘만들었다고 생각한다.
# 4.0
# 지구를 지켜라. 신박함도  지켜라
# 4.0
# 미친놈은 약도 없다 에서 끝났음 좋으려만 내 뒷통수를 까버리네
# 3.5
# 엔딩크레딧 ㅠㅠ
# 3.5
# 아우~발칙해 그런데.. 중간에 잠깐.. did a shit...
# 4.5
# 괴랄하다
# 하지만 패기롭다
# 그리고 서럽다
# 5.0
# 괴작
# 5.0
# 코미디의 본질을 아는 감독. 지금 보면 약간 낡은 대사들이 많지만, 화면 사용과 신하균을 중심으로한 갈등구조는 최고
# 4.5
# 지금도 우리는 사회를 좀먹는 외계인과 살아가고잇다
# 3.5
# 미친 세상은 평범한 사람을 미치게 만들고 미친 사람은 지켜보는 사람을 슬프게 만들었다
# 5.0
# 한국영화 역사상 이토록 독창적이고 슬픈 sf영화를 본적이 없다.
# 4.0
# 한국의 타란티노 감독느낌 B급 감성으로 시작되 A급 으로 기억되는
# 4.0
# 진짜 여러의미로 충격이었다.
# 솔직히 충격이라기보다는 골때렸다.
# 극장에서 봤는데 아직도 생각나는 뭔지 모를 아릿함.
# 2.5
# 진짜 이런 내용인지 몰랐다. 근데 누구라도 이런 내용일 줄 몰랐을 거 같은데.
# 아무튼 신하균의 뽀송한 얼굴, 빙구와 미친놈을 오가는 단짠 모먼트를 보는 재미가 있었다.
# 4.0
# 한국형 코믹 드라마
# 3.0
# 싸이코 영화 같지만.
# 5.0
# 결말을 <판의 미로>처럼 살짝 암시하는 식으로 열어만 놨다면 진지하기만 했을 텐데ㅋㅋ 확실하게 코미디로 간 점이 좋았다. 그리고 은근히 캐스팅과 인물 안배가 좋았던 영화 bb
# 4.0
# 편견을 과신하면 일어나는 결말.
# 4.0
# 들어보기만하고 계속미루다 이제야보았는데 오랫만에 재미있는영화를 본거같다
# 3.0
# 마케팅 실패의 표본이 된 비운의 작품
# 4.5
# 장준환 감독, 그의 출발은 화려했다.
# 4.0
# 미친척 하지마 이 미친놈아
# 2.0
# ㅋㅋ외계어 중국어냐
# 4.0
#
# 4.0
# B급은 풰이크다 이 녀석아
# 1.5
#
# 2.0
# 굳이 반전이 있었어야 했나?
# 3.5
# Ari Aster의 introduction으로 시작한 SAVE THE GREEN PLANET!
# @ Film at Lincoln Center. Walter Reade Theater. Fri. Nov 22, 2019. 9:00 pm.
# 3.5
# 계속 이상한 영화인데 마지막에 블랙코미디가 확!! 다가옴
# 3.5
# 생각하는 바를 끝까지 밀고 나간다.
# 2.0
# 기괴하고 난해하다
# 3.0
# 쓸데없이 잔인한가? 라는 생각을 했지만 이 영화의 색깔을 만드는데는 필요한 요소였음
# 2.0
# 난 어디.. 여긴 누구..
# 4.5
# 2000년대 초반의 엽기 감성으로 블랙코미디 스릴러 액션 sf등 여러 장르를 마음대로 넘나들며 관객을 가지고 놀고 사회의 부조리에 대한 메시지까지.
# 스페이스오디세이에 대한 오마주도 재미있는데, 그 부분의 연출이 아주 좋다.
# 3.5
# 설마가 사람 잡는다
# 4.0
# 외국에 ‘판의미로’가 있다면 우리나라에는 ‘지구를 지켜라’가 있다.
# 3.5
# 근래 본 영화 중에 제일 이상한 영화.
# 4.0
# 반전과 시대를 앞서 나간 영화!!
# 4.5
# 19.11.14
# 3.5
# 엔딩이 사람을 울리네.....
# 3.5
# 70
# 4.0
# 이 작품이 왜 논란? 이었는지 이제야 알게 되었다
# 5.0
# 진지하게 코미디는 이렇게 만들어야한다
# 5.0
# 저딴게 전부인 지구와 인류는 다 뒤져도 싸게 먹힌거임
# 3.5
# 모든게 미친 영화
# 병맛으로 가득 찼는데
# 속을 들여다보면 스릴러로 한가득
# 3.0
# 찾아봐야 볼수있는
# 4.0
# 이제 지구는 누가 지키지
# 5.0
# 평생 안 잊혀질 지독한 농담
# 4.0
# 2000년대 초반 불안정한 시대적 소용돌이 속에서 꽃피운 도전정신과 순애보의 사랑의 끔찍한 혼종
# 3.0
#
# 5.0
# 현대미술을 보고싶다면-
# 5.0
# 나에게는 완벽한 결말
# 4.0
# .
# 1.5
# 포스터때문에 망했다고?
# 3.5
# 소문으로 듣던 명작을 4k remastered 버전으로 봄.
# Kofa
# 4.0
# 새로운 시도, 그리고 보여지는 삶
# 3.5
# 이제 지구는 누가 지키지
# 3.5
# 코믹... 납치극....?
# 3.5
# 지구를 지켜라ㆍ37
# 5.0
# “이제 모든 걸 아는 건 너밖에 없어. 지구를 부탁한다.”
# 4.0
# 한국에서 가장 잘 만든 SF
# 3.5
# 존나 겉잡을 수 없다
# 2.0
# 숨겨진 명작이라고?
# 자신은 볼줄 안다는 지적 허영심에 빠진 자들
# 4.0
# 뭐 이런게 있냐 싶은데 중간에 끊을수가 없다.
# 3.5
#
# 2.5
# 음... 난 사실 혼란스러워.. 막눈인가봐 내가...
# 뭐.. 인간들이 발전하려는 욕구로 약자를 파괴하고.. 기득권은 거기에 동조하니, 거기에 미쳐버린 피해자가 지구를 지키겠다는 아이러니인 것은 들어오는데..
# 으음.. 그치만 혼란하다.
# 4.5
# 블랙코미디의 정수
# 4.0
# 어디로 튈지 예상할 수 없는 럭비공 같은 영화
# .
# B급 정서로 너무 가는 게 아닌가 싶다가도 진짜 끝까지 가는 게 또 매력이다. 거대한 권력 앞에 무력한 일개 개인은 실성할 수밖에 없는 세상에서 감독도 미쳐버리기를 선택한 게 아닐까. 소외당한 이들에 대한 이야기인 만큼 통상적인 형식에서 탈피한 영화의 문법마저 하나의 미학적인 태도라는 생각이 든다.
# .
# 혹자는 영화가 폭력을 정당화 하는 것이 아니냐고 비판을 가할 수 있지만, 나는 그렇게 생각하지 않는다. 폭력에 당위성을 부여하는 것은 전사의 위치에 달려있다. 요컨대, `테이큰`의 경우 극 초반부터 주인공의 사연을 전시하기 때문에 앞으로 그의 행보가 모두 정당화되는 것이다. 하지만 `지구를 지켜라`는 병 구(병든 지구)의 비통한 역사를 극 중반에야 제시하며 그렇기에 관객은 병구에게 온전히 이입하지 못하기에 그의 복수가 정당하다고 느끼지 못하는 것이다. 플래시백은 오로지 시스템 앞에 무력한 약자의 고통을 보여주는 역할로써 기능한다. 따라서 영화가 그의 행동을 긍정한다고는 보기 힘들며 이는 그가 어떠한 최후를 맞이하는지만 보아도 알 수 있다.
# .
# 영화의 엔딩에 대해서 말을 하지 않을 수가 없다. 사실 극 후반에 강 사장이 승리를 한 후에 그냥 현실적인 선에서 끝낼 수도 있었을 것이다. 모든 것은 병구의 과대망상이었을 뿐이며, 강 사장은 위기의 순간에 기지를 발휘하여 그럴듯한 이야기를 만들어 병구를 속인 것으로 말이다. 이렇게 마무리되더라도 몇 가지 복선에 대한 의문이 남을지언정 그것은 의문일 뿐이고 이야기를 매듭짓는 데에는 문제가 없다. 하지만 감독은 엔딩에 있어서 아주 파격적인 선택을 하며 나는 이 선택이 아주 탁월하다고 생각한다. 일단 관객의 상상을 초월한다는 점에서 이전까지의 영화의 톤과 같은 기조를 유지한다. 또, 병구가 쓰러져 가면서 남긴 `지구는 누가 지키지?`에 대한 답으로 감독은 이런 지구는 지킬 필요가 없다며 위로를 건네는데, 이를 초현실적인 방식으로 전달 함으로써 자칫 노골적으로 느껴질 수 있는 지점을 영리하게 비껴간다.
# 3.5
# 비운의 영화
# 3.5
# 이토록 경쾌한 오프닝과 이토록 슬픈 연쇄 살인범이라니. 결론은 외계인이었을지언정 병구가 겪은 과정은 인간의 소행이었다. 답도 없는 이 세계에서 지구인은 어찌 살아야하는고
# 2.5
# 인간이 지구를 대표한다는 감독의 오만함
# 3.0
# 지금보니 참 세련됐다.
# 4.5
# 연쇄 살인을 하려면 자기와의 연관성이 특정되지 않도록 전혀 상관없는 사람도 죽여야되는거구나
# 근데 강사장 뒤질 각 세워놓고 병구 일기 읽고 다 때려부수는거 좀 이해 안감
# 다 알면서 어디있었냐고 미쳐갈때까지 뭐했냐고 할 때 퍄
# 백윤식 독백씬 재미없다
# 결말 처절하고... 백윤식이 머리 굴려서 썰푸는거 존나 대단하다 특히 그 계산ㅋㅋㅋㅋㅋㅋ 강사장의 생존력 진짜 오졌고...
# 아 진짜 오히려 찐 외계인이었다는게 더 별로다 영화 완성도를 떨어뜨리는 느낌
# 미저리같은 느낌인데
# 4.0
# 마케팅 실패의 표본으로 기리기리 남을 영화
# 2.5
# 어머니 생일은 뭐 매년 있나?
# 내가 미쳐갈 때 어딨었어
# 2.0
# 과소평가라해서 봤는데 생각대로던데. . .
# 계속숨겨놓아도 될듯
# 포스터와 마케팅때문에 망한게 아니라 그냥 그정도의 영화인듯하다.
# 정말 좋은 영화였다면 입소문으로 흥행했다.
# 인터넷이 없던 시절도 아니고
# 4.5
# 괴작의 탈을 쓴 수작,
# 괴기스럽고 부산스러운 전개와 설정들은 보는 내내 마음을 갈팡질팡하게 만들지만 그 안에 묵직하게 들어있는 메시지는 결국 마음을 울렸다.
# 그의 내막을 알고 나서 다시 생각하게 되는 것 ,관객이 주인공과 함께 미쳐가는 듯한 흐름은 정말 감각적이다.
# *능력있는 베테랑도, 패기 넘치는 똑똑이도 결국 해결하지 못한 사회 문제
# *염세주의적 관점으로 인간을 바라보는 제 3자의 입장
# 3.5
# 아무 것도 없는 지구. 이 행성엔 희망이 없다
# 4.0
# 부당함과 무관심이 새긴
# 상처의 악순환
# 그리고 무망함
# 4.0
# 2019.08.30
# 야...내가....뭘본거냐....
# 2.0
# 나 혼자 다른 영화를 본 걸까
# 왜 난 이 영화를 못 봐주겠지
# 5.0
# 사회적 약자의 불행이 차라리 외계인의 소행이길 바랄만큼 썩어버린 사회의 모습. 이에 대한 지독한 환멸.
# 2.5
# 그냥 그래요
# 3.5
# 수작이지만 흥행은 절대불가 거품이 있으나
# 이런 장르의 한국영화를 다시 볼 수 있을까
# 2.5
# 예전 나이에 볼 때는 몰랐는데 지금 다시 보면 생각보다 생각할 거리나 내용이 많은 진지한 영화였다.
# 3.5
#
# 3.5
# 기괴한 유머와 어두운 상상력의 조우.
# 4.5
# 마지막까지 미쳤닼ㅋㅋㅋㅋㅋ
# 3.0
# 포스터가 망쳤어..
# 4.0
# 외계인의 잘못된 실험
#
# “고통은 익숙해지지 않거든”
# 5.0
# 포스터가 다 배려놨다. 역작임은 분명한 사실.
# 3.0
# 너무 큰 기대를 했나
# 3.5
# 👽
# 4.0
# 말하고자 하는 메세지가 정말 똑바르고, 그 메세지를 전달하는 데에 있어 영화라는 매체를 사용함에 있어 잘 만든 영화라고 생각한다
# 그것과는 별개로 신하균에 대한 애정으로 두시간을 버틸 수 있었다 허허
# 3.5
# 이상해서 좋아
# 3.5
#
# 3.5
# D급 포스터, C급 마무리, A급 전개가 합쳐져서 B급이라기에는 묘하게 잘만든 영화
# 4.0
# 몰입된다... 배우들 연기 정말 잘한다
# 4.5
# 영화가 지구의 업(業)을 외계로 돌릴 수 밖에 없었던 이유..
# 3.5
# 괴팍하지만 나름 알차게 메시지를 적재적소 채워넣었다
# 5.0
# 스토리의 짜임새가 대단한 영화
# 젊은 신하균의 연기도 참신했다
# 3.5
# 솔직히 숨겨진 명작까진 모르겠는데
# 포스터와 제목의 중요성은 느낀다
# -
# 지구를 지켜주기엔 지구는 너한테 너무 가혹한걸😿
# 1.5
# 너무 싫다
# 3.0
# 노골적으로 B급인 영화지만 너무 진지해서 뭔가 큰 의미가 담겨 있을 것 같은 기분
# 3.5
# 면제권 세 장 드립니다.
# 4.5
# 신하균 와.....
# 4.0
# 한국영화 중 가장 기발하고 황당한 영화.. 현실을 제 멋대로 비꼬는 최고의 영화... 실험정신에 감독에게 박수를...
# 4.5
# 지켜볼게 지키지 않았지만
# 4.0
#
# 4.5
# 이게 진짜 반전이지
# 2.0
#
# 4.0
# 앞서간 병맛
# 3.5
# 보면서도 믿을 수 없는 스토리 전개. 전주국제영화제에서 큰 스크린으로 보게 되었는데 다른 관객들과 다같이 실소를 터뜨리면서 보니 더 재밌었다. 황당한데 심오하고, 웃긴데 슬프다. 이러한 스토리에서도 배우들의 연기는 빛이난다.
# '그런데 이제 지구는 누가 지키지?'에서 울컥.
# 3.5
# 기이하게 잘 만든 영화. 나쁜~~ 외계인.
# 3.0
# 뭐야...
# 1.0
# 물파스가 이렇게 위험한거입니다 여러분
# 4.0
# 이 의미를 전달하기 위해 풀어낸 이야기가 진부하지 않아 신선하다.
# 4.0
#
# 2.5
# 2019년개봉이었으면 조현병, 갑질 화제모으고 흥행성공했을텐데.
# 3.5
# 동정표를 주어도 살인자라는 사실은 변치 않기에 결말을 그렇게 준것이 아닌지.
# 4.0
# 그럼 그렇지, 외계인이 아니고서야 이렇게 살았겠어.
# 4.0
# 2019.05.04
# 4.5
# 절절한 SF스릴러가 나온지 16년이 지난 지금 현실은 여전히 디스토피아다.
# 3.5
# 명성만큼은 아니었지만.
# 5.0
# 신하균 말대로 돼서 다행이다
# 3.5
# 힘이 지나치게 들어간 스토린데 그게 마음에 든다. 편안히 보면 평이할지 몰라도 곱씹어보면 생각할 거리가 많은 영화
# 4.5
# 그냥 마냥 b 급 영화인줄 알았는데
# 의외의 선전
# 4.5
# 이 작품 하나만으로 장준환에게 반할 수 있다.
# 3.0
# 신하균의 순수하면서도 광기어린 연기가 기억에 남는다
# 4.0
# 포스터만 제대로 만들었다면....
# 4.5
# 코미디 딱지는 떼야함
# 잘만든 스릴러. B급 감성에 약간 촌스럽지만 심리 갖고노는 건 수준급
# 3.0
# 외계인탓으로 돌리기엔 요즘은 사탄도 쪽을 못쓰는 판국이다
# 3.0
# 엉망이된 지구
# 4.5
# 정말 보고 싶었었던 영화였는데 마침내 봤다. (Netflix)
# 너무 잔인한 장면들이 많이 나와서 보기힘들었는데 그래도 재미있어요.
# 4.0
# Eloi, Eloi, lama sabachthani
# 3.0
# 헤쳐 놓은 건 많은데, 그걸 수습하려 클리셰한데 세련된 척 하려다 목에 걸려 켁켁 되다가 플래시백 과다복용하는, 개연성 보여주려다 개연성 스스로 없애는, 마지막에 찍은 거 아까우니까 크레딧에 영상첨부하는 영화.
# 3.5
# 너무나 시대를 앞서나갔다.아쉽다.
# 4.0
# 포스터의 중요성
# 4.5
# 비극적인 삶을 그려내는 강렬하고 세련된 장면들
# 지구를 지키지 못한 게 아쉽다
# 우리는 어떻게 될까?
# 1.0
# 뭐라구...?
# 4.0
# 살짝 박찬욱 감독의 스멜이
# 3.5
# 더 나은 존재들이 혹여나 우릴 보면 우릴 용서할까.
# 4.0
# 경고의 메세지!!
# 3.0
# 크크
# 4.5
# 한국형 SF의 모범예
# 5.0
# 블랙코미디? 아니 현실이 이렇잖아
# 4.0
# 미친 사회의 표본으로 살아가는 불쌍한 지구인들
# 4.0
# 캐릭터의 입체성이 완벽하다.
# 실패한 혁명과 구원받지 못한 주인공.
# 그러나 그만이 진리를 알았고 자유로웠다.
# 4.5
# 정말 띠용?해서 기억에 남는 영화
# 백윤식, 신하균의 연기력은 압도적
# 지구는 지켰을까...?
# 3.0
# '5분뒤'라는 걸 안 알려줬다면 더 흥미진진했을까. b급 감성의 과한 연기와 드라마틱한 인물설정.
# 3.5
# 진짜 포스터 디자인한사람 진짜 영화 망하는데 일조함. 코믹한 줄 알고봤더니..
# 4.5
# 어렸을때 아버지가 왜 못보게하셨었는지 이제야 이해가 가요. 아버지는 날 지키고 싶었던거겠죠
# 3.5
# 뒷이야기를 아주 조금 덜어낼 수만 있다면
# 3.5
# 미친 사람을 만든 미친 세상에 대한 미친 영화
# 5.0
# 포스터가 망친 영화라던데 보고 나니까 영화와 가장 잘 어울리는 포스터 같다.
# 5.0
# 기발한 설정
# 5.0
# B급인척;
# 4.5
# 한국영화 중 드물게 결말이 어떻게될까 진심으로 궁금했던, 겉만 번지르르한 대중영화보다 훨씬 성의있는 B급 영화
# 3.5
# 진정한 b급이 a급을 넘어선 영화
# 입뽕작이라 더 신선했으려나...
# 4.0
# 진짜라는 반전. 그래서 참신하다.
# 4.5
#
# 3.5
# '그들'을 외계인이라 믿고 싶은 현실.
# 3.5
# 그토록 지킬만한 것이었는가에 대하여 면전에 대고 소리치듯 토하는 울분.
# 4.5
# ㅜㅜ 너무 내 취향이다 신하균이 이런 배우였구나 ...
# 4.0
# 백윤식,신하균 연기 잘함
# 반전의 결말 충격적이며 재밌었음!!
# 3.5
# 저 행성엔 더 이상 희망이 없어.
# 난 그렇게 생각하지 않지만 그렇게 생각할 수 밖에 없는 사회가 되어가는 것 같다
# 3.5
# 지구를 지키기 위해 타협하지 않는 뚝심
# 5.0
# 충격과 공포 그리고 똘끼
# 4.0
# 불행에 이유가 있었더라면 위로가 될까
# 3.0
# 명작이라기엔 좀 혐오스러운 장면이 많다.
# 4.5
# 내가옳았다는허무
# 4.0
# 볼만해요.
# 4.0
# 포스터가 좋았더라면 모든게 완벽했을거야..
# 4.0
# 근성의 강만식.
# 2.0
# 포스터가 망친 수작이라고 하면서 정작 그 이유를 물으면 대부분 잘 설명해주지 못하는 영화.
# 4.0
# 아까운 수작.
# 2.5
# 무슨 생각으로 이 영화를 만들었을까.
# 4.0
# 너가 왜? 많은 사람들 중에 하필이면 너가 왜?
# 5.0
# 이 모든 해프닝의 시작은 병구가 사회로부터, 사람으로부터 받은 상처였다
# 4.0
# 이 미친 놈은 뭐야.. 싶었는데..
# 3.0
# 병맛 영화지만 나름 탄탄한 스토리
# 4.5
# 한국에도 이런 영화가 있다는 사실이
# 감사할 따름
# 3.5
# 인간이여, 인간들로부터 지구를 지켜라!
# 3.0
# 뭐라고 정의내리긴 힘들지만
# 엉망이진 않은 느낌이다
# 4.0
# 끝까지 음? 음? 음??
# 4.5
# 지구를 지키느라,
# 미쳐버린 우리의 모습
# 그리고 마지막 희망은 사랑.
# 4.0
# 독립영화 같지만
# 반전에 놀라지 않을 수가 없었음
# 3.0
# 띠용?
# 3.5
# 외계인의 짓이 아니면 미쳐버릴 병맛같은 삶의 파괴적 탈출구, 어쩌면 가장 병구를 위한 엔딩이었을라나
# 1.5
# 포스터때문에 망한 수작이라는 소리를 듣고 찾아봤는데, 망작 포스터 뒤에 숨어 수작이라는 평가를 받는 평작. 영화를 본 뒤엔 포스터가 괜찮게 보인다던데 나도 영화보고나니 그냥 그 수준에 맞는 포스터 같다.
# 한번쯤 상상해볼법한 뻔한 전개의 반전 플롯인데 데뷔작이어서 이런 시도를 할 수 있었다는 느낌. 영화 자체에 천재성이나 세련됨을 찾아볼 수 있는 부분은 없음 그저 그 시대에 딱 맞는 연출과 분위기 등장인물들
# *
# 폭력은 정당화될 수 있는가 하는 주제와 감독 개인의 관심사인 외계인을 대충 섞어서 자기 마음대로 고어 요소도 좀 넣고 후루룩 만들어낸것같음... 다만 영화의 의도 자체는 나쁘지 않다.
# 어떤 상황이든 결국엔 권력자가 승리하는 구조, 개인과 소시민은 자본과 권력 앞에 복수조차 성공할 수 없는 현실, 또 당시 대두됐던 반도체 공장 노동자 백혈병 사건 등을 적절히 풍자한 듯함. (감독이 사회적이거나 역사적인 소재, 그리고 판타지적인 요소를 좋아하는 듯하다. 최근작으로는 화이, 1987)
#
# 신하균과 스릴러 블랙코미디를 좋아한다면 킬링타임으로 볼만하나 굳이 찾아볼만한 영화는 아닌것같다. 한마디로 그냥그럼.. 하지만 당대의 논란이 되는 사회적 사안에 대해 이런 방식으로 연출해낸 건 괜찮은 부분인 것 같음. 개인적으로 좋았다. 영화나 드라마에서 현실 그대로를 보여주면 다수의 대중 관객들은 불편해짐.
# 물론 현실을 묘사하고, 그 현실을 모르던 이들에게 알려주고, 수면 위로 끌어올려 공론화하고, 작품으로 남겨서 다음 세대에도 시대상을 전달해준다는 점에서 의의가 있지만,아무래도 상업영화에서는 한계가 있다.
# 그래서 감독도 아마 비슷한 생각으로? 너무 무겁게 진지해지지도 그렇다고 가볍게 우스워지지도 않게 적당한 선에서 경각심을 심어주는 느낌~ 그게 외계인 소재였던거고. ㅋㅋㅋㅋ(진짜 터무니없는 외계인 묘사) 결국 악이 승리하면서 결국에는 현실과 결을 같이하지만 '하하 비급영화한편봤네~'하고 웃어넘길 수 있도록
# 3.5
# 병구가 안쓰러워서
# 이상하게도 다시 생각이 난다.
# .
# .
# 2000년대 초반의 신하균은 참 아련하다.
# 류도 되고 병구도 되는,
# 3.0
# 그럭저럭 볼만했다 마지막 부분이 없었으면 여운이 있었을것같은데..
# 3.0
# 지구의 용사은
# 아빠도, 엄마도, 연인도, 순이도, 자신도 지키지 못했다.
# "너희는 나를 절대 못이겨"
# 4.0
# 너무 처절해서 지키기 보다는 놓아주고싶은 지구
# 2019.01.03
# 이렇게 피가 난무할거라고는 생각지 못했지만 그래도 좋았다. 데뷔작이기에 볼 수 있는 듯한 독창적인 아이디어와 처절한 연출이 뛰어나다. 가만 보다보면 그들은 외계인이 아닌가 싶을 때가 있지. 그리고 형사의 말대로, 존나게 들여다본 병규는 확신을 가질 수 있었을 것이다.
# 2020.05.08
# 아리 애스터의 최애 영화라더니,, 리메이크까지 되는 구나 신기하다
# 3.5
# 병구의 과거가 약간 가볍게 던져졌다는 느낌이 강하다는 것 외에는 만족
# 4.0
# 과소평가당했다는이유로과대평가받는다고과소평가하기엔
# 잘 만든 영화
# 5.0
# 너무 슬픈 영화
# 3.5
# 정말 끝까지 알 수 없었던 문제작
# 2.0
# 왜들 그래
# 4.0
# 심오하면서도 헛웃음나면서도,, 설마? 하는데 그대로 때려박아버리는 블랙코미디,, 와이에무아이크라잉..
# 4.0
#
# 4.0
# 이런 영화가 우리나라에서도 많이 만들어졌으면 좋겠다.
# 5.0
# 정신이 약간 몽롱해지는 새벽에 보기 좋은 영화
# 4.0
# 지구엔 희망이 없어...
# 4.0
# 뉴스를 볼 때마다
# 외계 왕자 역시 당신이 옳았어!를 외치게 된다
# 4.0
# 어우 이 상상력은.. 미쳤습니까 휴먼?
# 3.0
# 신선하긴 한데 너무 짬뽕해서 맛이 뭔질 모르겠네.
# 3.5
# 수 많은 컬처와 영화 레퍼런스들를 놓쳤다면 옛날 명작들을 다시 보고 돌아오자.
# 일단 블레이드러너, 혹상탈출과 스페이스 오디세이는 꼭 보자
# 3.0
# 약을 LD50로 드셨네...
# 4.0
# 그럼에도 불구하고 달려온 처절한 사람들의 인생과 한 사람의 인생.
# 고정관념과 편견을 꺼내어주는 바보들과 바보의 바보같은 이야기.
# 그럼에도 불구하고 대지약우.
# 5.0
# 병구는 미쳤다
# 왜 병구가 미친건지, 병구를 미치게 만든게 누구였는지 볼 때마다 되새김질하게된다.
# 병구가 이렇게 되기까지, 우리를 포함한 모두의 책임이 있다.
# 병구의 인생은 고통의 '실험' 이라고 해야 이치에 맞다. 현실이라고 하면 말이 안되니까
# ㅡㅡㅡ
# 내 감수성을 강렬하게 자극한 촉발제의 영화였다.
# 한 사람의 인생부터해서, 나치의 만행, 전쟁, 가난, 독재 등 폭력에 대한 비난을 통하여 연민을 느끼게 해준 영화이다.
# 4.0
# 고통으로 성장한다는 말은 착취하는 자의 은유일지도. 믿고 싶지 않았으니 믿을 수 없는 존재를 불러들인거겠지.
# 4.5
# 혼자만 아는 진실로 무언가를 바꾸기엔 너무도 약한 존재였으니
# 4.0
# 비급장르에 대한 흥미를 가져온 작품
# 4.0
# 포스터에 비해 많이 슬픈 영화
# 4.0
# 1. 코믹sf  영화인줄 알았는데 매우 사실적/현실적인 슬픈 영화였음
# 2. 외계인의 존재는 감독의 병구에 대한 연민과 애정이라고 생각
# 3. '벌'이 나오는 장면은 너무 기발해서 박수칠 뻔
# 4. 배우들 연기가 미쳤다!
# 4.5
# 지키고싶다! 지구를!
# 3.5
# 괴작을 지켜라
# 3.0
# 기대하지도 않은 한국 CG...
# 포스터로 인한 반전영화
# 평타이상의 내용
# 4.5
# (병구가) 믿는대로 흐른다.
# 3.5
# 미-묘
# 4.5
# 소재, 주제, 플롯, 캐릭터, 유머 모든 것이 조화로운 웰메이드 한국영화.
# 4.0
# 포스터... 포스터....
# 2.0
# 블랙코미디는 좋아하는데 중후반까진 그렇다치고 결말쯤에 가서는 잘 모르겠다. 글쎄.
# 4.5
# 소수자의 잔인한 세상을 향한 단말마.
# 3.0
#
# 4.0
# SF 볼모지에서 탄생한 SF 돌연변이.
# 2.0
# 넘나 잔인한 것..
# 5.0
# 어릴 적에 봤지만 충격이 강했고 강한 인상을 남긴 영화. 흥행은 실패했지만 그래도 다시 재평가 되어서 다행. 마케팅의 중요성.
# 3.5
# B급과 A급을 넘나들기
# 4.0
# 모두가 틀렸다고 손가락질하는 사람이 맞을 수도 있는 것을...
# 2.5
# 내 취향 X
# 4.5
# 우스꽝스러운 외면 너머에 지독히 어두운 실상
# 병구를 병들게 한 원인이 병구 그 자신이 아님을 알면서도 외면했다면, 지구를 떠나라.
# 3.0
# 걍 b급 코미디 라고 생각하고 방심했다가 깨닫고 소름돋았던 영화 . 한국영화에서 처음 일본 특유의 병맛을 느낀 영화 ㅇㅇ
# 4.0
#
# 2.0
# 어떠한 것도 느끼지 못했고 초반에 기대감이 지루함을 이겨내지 못했다
# 5.0
# 반전영화로 짱붙으면 절대 이길수 없다
# 1.0
# 불쾌하고 기괴하기만..
# 3.5
# '내가 미쳐가는 동안 너희들은 어디있었는데?'
# 어쩌면 병구에겐 모두가 외계인이지않았을까
#  지구를 지켜라. 외계인, 아니 사람같지않은 사람들로부터.
# 4.5
# 최강 한국형 B급 영화.
# 4.5
#
# 3.5
# #지구 #그로테스크 #스릴러 #역설 #외계인
# 4.0
# 우리 사회에 남겨진 희망이란 건 있을까. 이제 지구는
# 누가 지키지?
# 4.5
# 또라이 같아서 좋은 영화다.
# 4.5
# 우주인의 존재에 집착하는 것이
# 지구를 지키기 위해서일까
# 지구를 떠날 희망을 위해서일까
# 3.0
# 오랜만이네이영화
# 4.5
# ㄹㅇ 웰메이드 영화 너무 재밌고 소름돋아,,,, 충격 그 자체
# 포스터 만든 사람은 머리 박고 반성해라
# 3.5
# 보고나서야 왜 포스터가 문제였는지 깨닫게 된다.
# 1.5
# 난 솔직히 재미없었음
# 4.0
# 이게 다 외계인들 때문이다
# 4.0
#
# 4.5
# 판의미로급으로 포스터와 마케팅에 숨겨진 걸작
# 4.0
# 이 영화가 과대평가 받는다고???
# 그럼 과소평가를 하지 말았어야지.
# 4.0
# 최근 논술 공부를 하며 느끼는 바는 문제점을 지적하기는 쉽다는 점이다. 그런데 이 문제에 대한 원인을 찾아내는 것은 많은 생각을 필요로 한다. 원인을 파악해야 해결방안이 나올텐데, 숨은 원인을 찾기란 매우 복잡하고 어렵다.
#  당하는 사람은 매번 당하고, 이기는 사람은 매번 이기는 모습을 대놓고 말한 영화, ‘지구를 지켜라!’. 이 영화는 그런 문제 제기에서 끝난 영화다.
#  이렇게 보는 것이 괴로웠던 영화는 ‘악마를 보았다’ 이후로 오랜만이다. 숨겨진 명작이라느니 하는 말은 많았지만, 왠지 손이 가지 않더라니. 결국 고향 가는 기차 안에서 할 일이 없어 혼자 괴로워하며 다 보고 말았다.
#  영화 중반까지 계속 강사장(으로 분장한 외계인 왕자)이 맞는 장면을 보여주더니, 후반에는 강사장(으로 분장한 외계인 왕자)만 산다. 기분이 더러웠다. 불쾌감을 이끌어내려했다면 뭐, 성공이다. 그런데 마지막에 외계인이 지구를 부술 때는 그 불쾌감이 영화 자체에게 옮겨 갔다. 이렇게 화나게 문제 제기를 해놓고 ‘아몰랑 인류는 멸망이 답이야’라는 건가?
# 음..
#  그래, 인류는 멸망이 답이다.. 지구에서 없어져야할 백해무익한 존재다ㅠ 공격성 인자에 오염된 인류 대신 강아지 ‘지구’를 지키자. 민족대명절 추석을 맞아 새롭게 다짐했다.
# 4.0
# 잘못된 마케팅은 후일 평가에 별 하나를 더하게 됩니다
# 4.0
# 이 감독 천재 아니면 또라이......
# + 신하균 백윤식 진짜 연기 끝내주네...
# 4.0
# 난 그냥 좋았다 마음이 아려서 분석하고 싶지도않고 그냥 봤다.. 신하균의 어두운 얼굴은 그의 미소를 더 밝게만든다 생각
# 5.0
# 이게 성공했었어야 장준환 감독이 더 자기입맛대로 영화를 만들 수 있었을텐데
# 4.0
# 감성주의
# 4.0
# 포스터만 바꿨어도...
# 4.0
#
# 3.0
# 아무리봐도 B급인데 왜 의미만은 A급이라고하냐.. 이거 두번볼수있으면 계속 A라고 하길..
# 4.5
# 병구야ㅠㅠ
# 5.0
# 포스터랑 홍보가 망친 대표작. 이걸 재미 없다고 하면 어떤 영화가 그리 재밌는거냐 대체?? ost까지 굳.
# 4.0
#
# 4.0
# 생각보다 잔인해서 깜짝 놀랐고
# 생각보다 비판적이어서 놀랐다.
# 2018/08/21
# 2.5
# 다들 엄청난 영화라고 한다. 그들이 열광하는 부분은 이해하겠으나 나와는 맞지 않는 영화였다.
# 2.5
# 멀리보나 가까이보나 파괴된 인간성.
# ...이걸 반전이라고 해야되나
# 3.0
# B급 포장을 쓴 A급 알맹이. 근데 나에겐 포장이 너무너무 중요한가보다.... 보면서 음오아예 파티
# 3.0
# 재평가를 재평가 해야...
# 3.5
# 명작을 가려버린 포스터....
# 5.0
# 무슨 이런영화가 다 있나......하고보다가
# 마지막에 띠용~!
# 1.5
# 과소평가의 과대평가
# 폭력은 폭력으로 정당화할 수 없다.
# 영화의 허용범위는 어디까지인가.
# 4.5
# 시각적 충격, 서사가 주는 몰입감, 공포스러울 정도의 캐릭터 묘사가 있는 보기 드문 수작
# 4.0
# 광기 아이러니 의미
# 4.0
# 안쓰러운 미친놈의 일생.
# 유독 그사람에게만 혹독한 세상이 있죠. 하루 빨리 미쳐라고 주문거는 듯한 세상.
# + 신하균은 무슨 연기를 해도 안쓰러운 구석을 꼭 남겨두는 배우같다
# 4.0
# 신하균이란 배우에 입덕하게 만든 영화.
# 영화의 마케팅이 얼마나 중요한지 알게해준 영화
# 4.0
# 흔히들 지적하는 포스터의 유치함이 이 영화의 기괴함을 더욱 돋보이게 해준다.
# 4.0
# 진짜 포스터땜에 안봤는데 마케팅 한사람 찾아서 물어보고싶다 의도가 뭔지 명작을 못보게하네...
# 3.5
# ‘지구를 지켜라’는 주류의 시선이 아닌 ‘비주류’의 시선으로 영화 속에서 투영된 세상을 바라볼 수 있게 해준다. 어쩌면 우리가 학창시절 배웠던 도덕과 윤리, 그렇다고 여겨져 왔던 사회적인 약속들, 그게 법률이든 관습이든, 너무나도 당연시 됐던 것들에 대해서 다시 한 번 생각해 볼 필요가 있음을 느끼게 해준다.
# 4.5
# 병구의 행복했던 일화들이 서사에 직접 드러나지 않아서 좋았다. 병구가 안테나를 통해 외계인에게 전달하고자 했던 건 그의 행복했던 기억들 아니었을까. 그 기억들은 지구가 멸망해도 영원히 우주를 떠돌 것이다.
# 폭력에 대처하는 폭력의 아이러니들. 외계인 당신들도 결국 지구의 일에 폭력적으로 간섭하는 것 아닌가!
# 포스터가 망친 영화라지만, 이 포스터 말고 또 어떤 포스터를 쓸 수 있을까. 뜻밖의 노림수였을지도...
# 3.5
# 주제를 끌어낸 것까지는 좋았지만.. 결국엔 노답이니 다 엎어버린다는 좀 많이 심각하게 아쉬운 결말ㅠㅠ
# 그를 미치게 만든건 세상 모두였다. 결국 답없는게 맞는건가? 답없어도 희망은 있지 않나..
# 4.0
# 병구를 미치게 한 건 외계인의 실험이었을까 아니면 지구 그 자체였을까
# 4.0
# 한국영화는 퇴보해왔군...
# 3.0
# 미쳤을수도 아닐수도
# 4.5
# 보는내내 가슴이 시렸다.
# 4.0
# 유쾌하면서도 기괴하고 씁쓸하게 염세주의를 컬트적 감성으로 버무린, 도저히 한국 영화같지 않은 한국 영화.
# 3.5
# 독특한 소재 그리고 함부로 다음 내용을 예상한 나를 반성하게 만드는 스토리 전개. 감독의 창의력에 감탄을..
# 4.0
# 황당한 이야기 속에 많은 것이 담겨있다.
# 5.0
# 데뷔작부터 공포와 코미디, SF판타지와 현실드라마, 웃음과 울음 사이에서 능수능란하게 오가는 장준환 감독의 걸작.
# 2.0
# 기괴하고불편
# 3.0
# 이런 영화를 접할 때마다 어렵다.
# 명작이라고 찬사를 받는 영화를 봤는데
# 도저히 왜 그런 찬사를 받는지 모르겠을 때...
# 영화 하수를 어떻게 벗어나야 하는가.
# 5.0
# 저퀄의 고퀄화
# 4.0
# 이상하다는 말의 정의를 바꿔야 할까.
# 3.5
# 산만하고 난잡함 괴작은 맞음 명작은? 60까지 쳐드리겠슴다 진짜 근데 8-90년대 선생들 교내 폭력 저지른 사람들 찾아내서 처벌 어케 못하나
# 4.5
# 인간의 자유의지의 끝은 결국 자멸인가.
# 3.5
# 결국 지구는 못지켰다. 설마설마하던 반전은 결국 맞았고. 모든 일엔 원인과 결과가 있다. 사필귀정
# 4.0
# - 영화 리뷰를 보고 흥미가 생겨 봤던 영화.
# 리뷰를 보지 않고 봤으면 또라이 살인마 병규의 이야긴 줄 알다가 뒤통수를 맞았을 것. 이미 '강사장은 외계인이다!'라는 전제를 깔고 봐서 그런지, 영화에서의 충격을 덜하게 받은 것 같다.
# 근데 또 리뷰를 안봤으면 내가 개봉 된 지 한참 지난 이 영화를 보려고 했을까?
# 5.0
# 어차피 희망을 잃었다면서 떠나버릴 거였다면, 왜 미치도록 불행하게 만들어버린 걸까.
# 5.0
# 달리면 달릴 수록.
# 끝으로 가면 갈수록
# 완벽해지는 결말로 향하는
# 상업 영화에 물들지 않은 데뷔 감독만이 낼 수 있는
# 완벽한 한국형 블랙코메디.
# 3.5
# 정말 포스터 누가했냐...
# 4.0
# 영화는 담담하고 웃긴데 나는 펑펑 울었다
# 4.0
# 장준환을 지켜야 한다.
# 4.0
# 고어물중 네가 최고다
# 4.5
# 겸손함을 배울 수 있는 영화
# 0.5개를 깍은 이유는 이 영화가 과소평가된 이유로 과대평가 됐다는 베뎃의 주장에 어느정도 동의하기때문
# 4.5
# 발상의 무한을 체현한다.
# 4.5
# 다 알면서도 속는 기분이란
# 4.0
# 시대를 앞서간 괴작
# 3.0
# 하지만 나의 다른 3점들과는 무언가 다르다고 말하고 싶다.
# 5.0
# 장르를 뛰어넘는 뭔가 엄청난 영화. 진실
# 5.0
# 뒷통수맞고 뒷통수맞고 뒷통수맞는
# 4.0
# 미친 척 그만 해 이 미친놈아
# 5.0
# 믿기지 않는 두가지 이야기로 현실을 들추는것
# 4.5
# 개그 영화라고 생각하고 봤다가
# 뒷통수를 심하게 맞은 영화
# 1.5
# 기대를 정말 많이 했다
# 워낙 유명한 작품이니까
# 막상 보니 너무 심오하고 섬뜩했다
# 완벽한 건 신하균님의 연기 뿐 ,,
# 5.0
# 한국미친sf
# 3.0
# 숨겨진 명작이란 이름으로 과대 평가된 느낌이 있다. 좋은 영화가 꼭 흥행하는 법은 없지만, 흥행 못한 영화는 항상 이유가 있다.
# 4.5
# 2000년대 저주받은 걸작이자 가장 인상적인 감독 데뷔작. 기발한 상상력과 통렬한 사회비판, 사회적 약자에 대한 배려가 잘 어우러진 발칙한 코미디
# (KOFA, "발굴, 복원 그리고 초기영화로의 초대"프로그램  중 섹션1.걸작의 재발견, 2018.5.16)
# 4.5
# 도데체 왜때문에 물파스 들고 웃는 주인공이 포스터인가요
# 5.0
# 발칙한 상상, 시원한 풍자, 그리고 다시는 볼 수 없을 것같은 구현력
# 4.5
# 포스터가 망쳐놓은 블랙코미디의 끝.
# 4.0
# 뭔지 모르겠는데 백윤식 아저씨 원피스 입고 연기하는게 자꾸 아른거려서 몇번째 봄
# 3.0
# 마지막 결말이 오히려 맘에 들어따
# 그러나 너무 올드한 연출....!
# 4.0
# 우리나라에서는 찾을 수 없던 종류의 창조적 집합.
# 4.0
# 장준환 감독의 데뷔작. 포스터만 빼고 모든게 좋았다
# 4.5
# 내가 봤던 한국영화 중 가장 괴상하면서 씁쓸한 영화.
# 4.0
# 이 영화는 일반적인 영화 감성으로는 이해하기 힘들다. 일단 포스터는 코믹처럼 보이지만 SF/스릴러고, 그나마 나오는 유머는 전부 풍자가 담긴 블랙코미디일 뿐이다. 거기에 영화 전반적으로 깔린 강한 B급 정서는 다른 영화와는 전혀 다른 분위기를 형성한다. 그러나 수많은 난관을 넘어서 이 영화를 날 것 그대로 감상할 수 만 있다면, 이 영화는 다른 영화보다 훨씬 강하게 우리에게 박힌다.
# 영화를 처음보면 병구가 악당이다. 그는 싸이코패스 살인마처럼 비춰진다. 그러나 병구가 대체 무엇을 잘못했는가, 병구는 외계인의 실험체로써 지옥같은 삶을 강요받고 그 속에서 고통스러워했을뿐이다. 만식은 반전 전까지 순수한 피해자처럼 비춰지지만, 결국 그야말로 진정한 악당이었고, 그게 밝혀지는 순간 영화 전체를 내내 지배하던 피해자와 가해자 관계는 순식간에 뒤집혀진다.
# 종반부까지 비판받던 병구의 행위들은 한 순간에 지구를 지키는 숭고한 행위가, 만식은 무고한 피해자에서 숨겨진 흑막이 되고, 이는 결국 우리에게 폭력이 옳을수 있는가? 우리가 마음대로 옳다고 판단해도 되는가? 같은 강렬한 메시지를 준다.
# 4.5
# 묵직하다
# 4.0
# 괴작과 명작 사이를 아슬아슬하게 넘나드는 기묘한 작품.
# 3.0
# 영화부심에 관한 부담감;;
# 2.5
#
# 4.0
# 무엇을 믿느냐 ...
# 어떤 종교든 존중해주쟈 ㅎㅎㅎㅎ
# 4.0
# 마음에 드는 괴작
# 4.5
# 올드보이 살인의 추억  지구를 지켜라
# 2003년 한국영화계의 트로이카
# 4.0
# 뭔가 병맛인듯 병맛아닌 무거워야 할 장면에 신나는 브금까지
# 내가 뭘 본거지 ..?
# 3.0
# 지금보니흥행에도움이안되는매니악한요소들을두루두루갖춘영화였네.지구가멸망하는엔딩은노잉말곤처음인듯...
# 4.5
# 영화다운 영화
# 3.0
# 한국 영화 대표 괴작하면 늘 리스트에 오르는 이 영화가 난 너무너무 궁금해서 언젠가 꼭 봐야하는데 하고 마음 한켠에 고이 모셔놨었다. 이 영화에 대한 인상은 그 때가 더 좋았던 것 같다.
# 3.5
# 옷 차림 간지남...
# 4.5
# 미친 명작
# 5.0
# 잔혹하며 진실되다. 나는 이런 영화가 많아져야 한다고 생각하면서도 이런 현실은 없었으면 좋겠다. 그리고 세상은 언제나 그 반대다.
# "병구야 안돼..."라는 말을 수없이 되뇌게 만드는 영화. 마음이 찢어질듯 아프다. 그 말밖에 남지 않는다.
# 3.0
# 표현하고자 하는 것은 멋지지만 사실 조악하다
# 3.5
# 아담과 하와가 선악과를 따먹었다. 인간은 과연 선악을 알게 됐을까. 세계 2차대전은 사회주의와 자본주의가 전쟁으로 대립 한다. 결국 미국의 승리로 끝이났다. 전쟁이 낳은 건 동족상잔의 비극, 이산가족의 아픔, 삶의 터전을 잃은 자들의 고통, 폭력으로 인한 인간성의 파괴까지 이어지면서 우리의 소중한 것들을 잃어가야만 했다. 인류의 사랑과 평화를 위해 우리는 무엇을 해야 할까.
# 2.5
# 마지막에 느닷없는 외계인 타령이란... 이유없는 잔인함과 황당함의 나열식 영화
# 4.0
# 존나 묵직한 주먹에 불알 쳐맞고 오는 단전에 통증
# 4.5
# 진짜 잘 만들었는데, 너무 잔인해서 나한텐 안 맞다...
# 2.0
# 이 영화가 그정도인가...? ㅠㅠ
# 이명세 감독 영화보다 더 난해하다....
# 5.0
# 메타픽션... 겉과 속 뒤집기.
# 3.5
# 만들 생각을 했다는 것도 신기하고
# 1.5
# 그닥...
# 2.5
# 이런 걸 데뷔작으로 찍다니.. 확실한 건, 감독이 제정신은 아니라는 거다. 사회비판은 성공했으나 이 영화가 포스터 탓에 과소평가되었다며 호들갑떨던 이들의 평을 보았던 내 기대에는 다소 못미쳤던 작품.
# 4.0
# 후루야 미노루의 만화같다.
# 3.0
# 그땐 별로였던 병맛코드가 왜 나이먹구 좋냐
# 4.0
# 무엇이 진실이고 무엇이 거짓인지 그 누구도 몰라!
# 1.5
# C급영화 맞음
# 4.5
# 얼렁뚱땅 아무말인데 말 됨
# 5.0
# "너, 그때 나한테 '겨'란 던진 그놈이지! 맞찌-!"
# 4.0
# 지구는 누가 지키노...
# 4.0
# 한국인에게 너무 일찍 온 영화
# 3.0
# 너무 끔찍해서 다 못 보겠음
# - 별로
# 4.0
# 신하균은 이 때 이미 완성되어 있었구나
# 4.5
# 완벽한 괴작, 그리고 데뷔작
# 4.0
# 받은 충격을 잊을 수가 없다
# 5.0
# 신하균 똘아이
# 4.0
# 2.19.2018 다시보다. 상당히 애매모호하고 아리까리한 느낌을 유지하도록 하는 반전영화. B급 고어 장르임에도 불구하고 진중한 톤으로 연기한 신하균과 백윤식이 빛나는 영화. 상당히 수작.
# 5.0
# "이 영화, 뭐지?" 하면서도 보게 되는 영화.
# 3.5
# 자유로운 동시에 강렬하다
# 3.5
# 너무 무거운 것들을 짊어지고 사는 사람들이 있다
# 미치지 않고 살아낸 그들의 오늘에 물파스 한 방울
# 4.0
# 분명 미친 영화인 것만큼은 확실하다.
# 3.5
# 스릴러인가 코메디인가 - 관객이 눈앞에 보여지는 장면을 어떻게 받아들여야할지 혼란스럽다. 다만 폭력에 대한, 무감각함에 대한 특유의 진실을 담고 있어서 가치가 있는 영화.
# 3.5
# 1987 러브포세일 지구를 지켜라 화이.... 모두 같은 감독이라고,,,,,
# 3.0
# 너무 많은 내용을 담으려 한 거 같은데..이게 왜 명작이지
# 4.0
# "미친척 그만해! 미친놈아!" 보는이도 미쳐버린다
# 4.0
# 반전이 쉽게 예상되면 반전이 아니다.
# 그럼에도 불구하고 B급 감성 제대로 저격했다.
# 4.0
# 맨처음에 백윤식이 술취해서 술주정한게..술주정이 아니였다
# 4.5
# 포스터 기획한 넘 언능 튀어 나와라
# 3.0
# 대충봄. 일단 영화 자체가 신선했음 특히 한국에서. 보면서 굉장히 폭력적인 고발이라는 생각이 들긴 했는데 유쾌한 점도 많아서 폭력성이 감소되는 느낌. 마지막 엔딩은 개인적으로 마음에 드는 결말이었음.
# 4.5
# 병구를 나라도 좀 믿어줄 걸 그랬네
# 3.5
# 은근 고어하다.
# 5.0
# 어쩌면 한국영화 최고의 역작
# 4.5
# 가장 자랑스러운 한국 영화
# 3.5
# 이렇게 섬뜩하고 기괴한 영화일 줄은 몰랐다 어쨌든 포스터가 잘못했다
# 내 눈에 보였던건 물파스를 손에 쥐어주던 순이의 사랑. 흘러나오던 <Over the rainbow>가 그녀에게 잘 어울렸다. 유전자고, 실험이고 뭐고 병구가 원했던 건 소중한 이들의 행복이었다.
# +가장 약한 자를 심판하는 자로 표현한게 재밌고 씁쓸하기도 했다. 감독이 영화에 계속해서 십자가를 활용하는데 심판의 의미를 항상 생각하는듯하다.
# +중간에 타인의 삶이 생각났다
# 3.5
# 고통의 기원은 지구인이야. 그럼 정말로 지구는 누가 지킬까.
# 4.5
# 찰흙으로 빚어낸 명화
# 4.0
# 병맛같은데도 진지함
# 5.0
# 어릴때 이 영화보고 미칠지경이엇다니깐
# 5.0
# 인간 : 사회 -> 지구:우주 혹은 우주:지구
# 4.0
# 신선하기 그지없다.
# 4.0
# 백윤식 캐스팅 최고.
# 4.0
# 우주에서 갑자기 툭 떨어진 것 같은 영화.
# 4.5
# 국가와 자본이 낳은 권력, 맞닥뜨린 개인
# 4.5
# 윗사람은 절대로 아랫사람의 분노를 이해못한다는 교훈
# 4.0
# 끈적끈적한 비급 코믹 스릴러. 지금 봐도 잘 만들었다.
# 4.0
# 포스터 빼고 다 좋은 영화
# 4.0
# 2003년영화를 2018년에봤지만
# 사회질서가 거부감 없이 이해됐다,,
# 사람이 같은 사람에게 할 수 없을 정도로
# 잔인한 사회를 사는 나에겐
# '외계'나 지금의'세계'나
# 난해하고 헛웃음만 나오는건 별반다름없다.
# 4.5
# 한국 컬트 무비의 신기루
# 4.0
# 10년도 더 지난 그때 한국도 이런영화를 만들 수 있구나라고 생각했었는데
# 아직까지도 이런 영화를 찾아 볼 수가 없다.
# 5.0
# 진짜 최고!!
# 4.0
# 보통 미친 놈이 만든 게 아니다...
# 4.5
# 한국영화계의 마의산
# 지향해야할 창의적인 시도
# 이런영화가 좋다
# 1.5
# 외계인이 아니라 지구인도 상처에
# 물파스바르면 아파...
# 4.0
# 신하균의 전매특허 연기. 십 년쯤 지난 <7호실>에서 보았던 신하균과 <지구를 지켜라>의 신하균은 크게 다르지 않다. 개성이 대단한 배우.
# 잘 만든 B급 블랙 코미디. 너무 좋았다. 결말도 훌륭했다.
# 그런 문장이 내내 떠올랐다. 영화 속 진짜 악역은 누구였을까. 내내 잔인한 행동에도 불구하고 나는 신하균이 안쓰러웠다.
# 2.0
# 이해가 안간다...
# 4.5
# 아직까지는 21세기 최고의 한국 영화.
# 4.5
# 뇌리를 스치는 신선하다 못 해 살아숨쉬는 충격!
# 5.0
# 내가 가장 좋아하는 한국영화
# 4.5
# 당신은 인간인가?
# 3.5
# 장준환 감독의 가능성과 한계가 다 담겨있음
# 5.0
# 이성은 편견의 늪에서 침잠한다.
# 5.0
# 시대를 잘못 만났다곤 하지만 지금 당장 개봉했다 해도 결과는 역시 참패였을 것이다. 한20년 뒤면 모를까..
# 한국영화에서 이렇게 참신한 상상력을 보여준 영화는 없는 것 같다.
# 마지막 결말은 현실을 비추어 볼 때 슬프다.
# 3.5
# 괴랄했던 영화의 진면목
# 3.5
# 스릴러야 SF야 코미디야 믹싱이 좋았어.
# 4.5
# 이런 생각을한 감독이 대단하다고느낀작품 한국에서 이런영화가 또 나올수있을까?? 다만 호불호가 갈릴수있는영화라 0.5점깍는다
# 4.5
# 진짜 이 영화 홍보한 사람은 죽어야 해..
# 3.0
# 포스터에 낚여서 보고 삼일밤낮을 설쳤다
# 4.0
# 개쩌는 이야기 전개와 컬트한 이미지
# 4.5
# 뭐야 이거 반전영화야?
# 3.5
# 백윤식은 외계인일까?
# 5.0
# 제발 포스터좀 잘 만들자!!!! 다시 없을 명작을 3류 개그 영화로 만들다니 ㅠㅠ
# 4.5
# 불행이 없이 모두가 행복하게 살 수 있는 세상은 거짓이다. 불행이 와도 그것에 무너지지 않고 일어설 수 있는 세상이 와야한다.
# 4.5
# 뼛속까지 힙스터
# 3.5
# ㅋㅋㅋㅋ 스릴러인줄 알았더니  진짜가 나타났다!!!! ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ
# 4.5
# 슬펏다. 내 망상과 분노도 슬픔애서 나오는개 아닐까. 소외된 지구인의 아픔을 누가 알까. 차라리 죽고나서 모든게 허상이라 믿고마리.
# 4.0
# 포스터만 더 잘만들었으면 하는 아쉬움
# 4.5
# 제목과 포스터의 중요성. 안타깝다..
# 3.5
# 미친 것 같지만 전부 사실이에요.
# 4.5
# 개 또라이 같은 B급 감성
# 감독은 천재다
# 4.0
# 독특한 발상과 B급 스타일이 잘 버무려져 해괴스러운 헛웃음이 작렬하는 신선한 재미를 느꼈다
# 4.5
# 올비플을 의도했기에 에이
# 5.0
# 장준환의 생각, 성공적인 작품, 실패한 마케팅.
# 2.5
# 그들이 미친게아니라
# 우리들이 미친것일지도,
# 그들이 어리석은게아니라
# 우리들이 이해할 수 없는것일지도,
# 3.5
# 너무 괴랄한 B급 공포 개좋아
# 3.5
# B급 감성의 매력.!
# 미치는 것 말고는 선택지가 없었던 병구에 의해 지켜지고 있는 지구
# 4.5
# 진흙 속에 감춰지 진주 같은 영화
# 2.5
# 아 뭔가 알것같으면서도 모르겠는데 아니 내가생각하는게 맞나싶다가도 그냥 헷갈림.......
# 나중에 다시 봐야겠다
# 4.5
# 포스터를 진짜 잘못 만들었음
# 3.5
# 초반에는 '엥'하다가, 후반에는 '헉'한다
# 4.0
# 결말이 뻔하지 않아서 좋았다.
# 3.0
# 솔직히 저는 잘 모르겠어요...
# 5.0
# B+B+B+B+B+B+......+B=A
#
# -
# 코로나는 그 결과인가용?
# 오히려 이 시대에 들어서야 더 믿음직한 아이러니
# 0.5
# ㅇ ㅏ 뭐라 말을해야할지....
# 5.0
# 엔딩크레딧 올라갈 때 나오는 장면 보고 맘이 참 먹먹했다 우린 얼마나 많은것을 놓치며 사는지.. 결국 지구는.. 막판에 왜 울었더라 ..
# 5.0
# 최고의 블랙코미디
# 4.0
# 보면볼수록 빠져들며 긴장감 있었고 슬프기도했다
# 외계인이 나오고 나서 부터는 패닉에 빠져 이건B급이다 싶었지만 다시 생각해보니 그들이 외계인이라는게 오히려 현실성 있는것 같다는 생각이 들었다
# 지구라는 개는 정말 재밋는 웃음포인트였다
# 4.0
# 충격적인 반전영화
# 5.0
# 고등학생 때였다. 영화를 보고 충격을 받은 것은 처음이었다. 지금까지도 이렇게 슬픈 광기와 파괴를 영화로 본 적은 없다. 시대를 앞서간 명작.
# 2.0
# 포스터에 의해 과소평가된작품이라...
# 4.0
# 유독 처절하고 구질구질했던 엔딩씬이 기억에 남는다. 끊임없이 거대한 누군가와 싸워야 하는 우리네 인생이 그렇게 처절하고 구질구질해서 그런가보다.
# 이제 지구는 누가 지키지?
# 로 끝나며 영화는 막을 내린다.. 그러게 이제 지구는 누가 지키지... 파괴된 지구에서 나오는 티비속 영상이 마치 이렇개 순박했던 봉구랑 순이같은 사람들은 이제 누가 지키지라고 물어보는 듯했다. 이제 지구는 누가 지키나 한참 생각하게 만들었던 영화
# 이렇게도 연출할수있구나 신선했던 영화였다. 그리고 순이 캐릭터가 참 좋았다...
# 3.5
# B급인줄 알았더니.
# 과감하게 들이대더니. 마무리까지 용기있게!!
# 5.0
# 한국영화계의 전성기 중 가장 괴상하고 기묘한 작품. 컬트적인 분위기에서 나오는 이상한 흡입력은 어느새 관객들의 뇌 속 깊이 경이로움이라는 뿌리를 내린다.
# 3.5
# 한국영화 중에 몇안될 독특하고 B급감성이면서도 완성도 높은 영화
# 4.5
# .
# 4.0
# ?8
# 3.0
# 정당화할 수 있는 폭력이 있을까...그리고 신하균의 대사. 알아? 다 안다고? 알 수 도 있었겠지. 뻔한 이야기니깐. 근데 다 알면서 어디 있었는데?  내가 미쳐갈때 어디 있었어?...니들이 더 나빠.
# 5.0
# 한국에서 이런 영화가 있을수가!!!
# 3.0
# 보는 내내찝찝한 느낌 뭔가 그냥 찝찝함
# 그래도 좋은 블랙코미디
# 4.0
# 강만식이 외계인이냐 아니냐가 중요한 게 아니다.
# 2.0
# 이걸 영화관에서 봤다면 정말 화났을 것 같다. 엄청난 영화라고 해서 봤는데, 과대평가에 낚인 기분
# 2.0
# 한국영화 다양성의 한 축. 컬트의 정서까지 더해졌다면........
# 3.5
# 보고 싶은 대로 보니 황당할 수밖에
# 4.0
# 병맛이라 하기엔 너무 좋다.
# 4.0
# 솔직히 처음부터 이 영화에 대한 평가를 전혀 모른채 보았다면 깊게 생각하지않고 머리 속에서 지웠을것이다.
# 아직도 멀었다
# 2.5
# 지금 생각해도 어떻게 이런 영화가 나올 수 있었는지 미지수
# 3.0
# 똥꼬 발랄한 영화인 줄 알았다
# 3.5
# 가지지 못한 자가 더 빼앗길 수밖에 없는 이 행성의 부조리함에 대한 고찰.
# 3.5
# 17.11.22
# 3.0
# 선과 악, 정상과 비정상의 경계는 불분명하게 느껴진다.
# 과연 어떠한 부정적 결과의 원인은 어디서부터 오는 것인가.
# 4.0
# 하도 좋다고 하길래 봐봤다. 나는 그냥 그저 그랬다. 칙칙하고 어두운 이야기를 새롭게 접근하려고 했던건 의미있다고 본다.
# 1.5
# 동화적 요소가 더 현실적일 줄이야
# 4.0
# 평때문에 기대를 너무 했나 명작이라기엔 너무 촌스럽다
# 4.0
# 차라리 영화처럼 외계인들의 소행이었으면 한다.
# 2.0
# 가볍게 시작해서 무거운 반환점을 돌아 다시 가볍게 끝나는 영화
# 4.5
# 명작이다 뭐다 그러긴 하던데,
# 3.5
# 가장 완벽하게 마음을 훔친 데뷔작
# 4.0
# 흥미롭게 봤지만 완전한 이해는 하지 못했다 하균신 팬이지만 백윤식의 연기에 감탄하고간다.
# 3.5
# 인간으로 변장한 외계인처럼 이 코미디 속에는 암울한 사회비판이 존재한다.
# 4.0
# 정말 저렴한하게 정말 무거운 이야기를 표현했다
# 이런표현을 영화에 쓰는게 어떨지 모르겠지만  가성비 지렸다
# 4.0
# 코미디로 위장된 브루주아지와 프롤레타리아의 대립
# 4.0
# 물파스 톡톡
# 4.0
# 이걸 우리나라가 만들었다굽쇼!
# 4.5
# 영화 잘 만들어놓고 포스터를 왜 그따위로 만들어서 10년만에 보게 만드냐!!!
# 4.0
# I TOLD YOU SO
# 3.0
# 잔인한 블랙 코미디..
# 청초한 그 시절 신하균은 좋은데 진짜 미친놈 같다
# 5.0
# 얘가 미쳤는지 쟤가 미쳤는지 내가 미쳤는지 미궁에 빠지는 영화
# 4.5
# 내가 가장 사랑하는 한국영화❤
# 5.0
# 제발 포스터좀....
# 2.0
# 영화 내내 미친놈처럼 악다구니 치던 병구는 어느 순간 눈이 풀리며 체념하듯 말한다.
# '내가 미쳐갈 때 어딨었어.. 니들이 더 나빠'
# 4.0
# 정말 홍보팀만 문제였을까?
# 4.0
# 싫어하는 장르&감성이지만..끝까지 흥미롭게 집중해서 봤다
# 4.5
# 사실 너무 끔직해서 중간에 좀 넘겼어.
# 4.0
# 기괴하다는 단어로는 설명되지 않는 영화
# 4.0
# 그 시대를 생각해보면 그야말로 정말 미친 영화.
# 4.0
# 병구가 알약없인 살 수 없었던 지구
# 왜 세상은 나를 내버려 두지 않을까
# 4.0
# 똘끼 터지는 슬픈 영화...
# (하균오빠 찌질한 순정파역할 할 때가 제일 좋아)
# 4.0
# 인생의 불합리함을 외계인의 존재로 재미있게 풀어낸 영화.
# 5.0
# ...
# 누가 설명좀 해달라고 때쓰고 싶은 영화.
# 4.0
# 설마... 설마...가볍게 보다가 뒤통수 맞은 반전. 세월이 가도 잘 기억나는 영화.
# 4.5
# 광고가 잘못되었다는 말을 이제 이해할 수 있었다. B급의 A급? 배우들 연기도 좋고, 담고 있는 주제도 매력있다.
# 4.0
# 포스터가 다 망친 영화
# 주인공 연기는 진짜..
# (결말빼고)내용도 연기도 좋았는데 너무 잔인해서 두번은 못보겟다
# 4.0
# 독특한 연출을 제외하고는 지킬 것이 별로 없었다.
# 3.5
# 영화 보는 중에는 뒷통수를 팍 치더니 영화 끝나면 무릎을 탁 치게된다.
# 2.0
# 오래전에 본영화인데 아직까지 기억에 남는영화
# 3.0
# 포스터 왜 저렇게...마게팅 망함류 갑 진짜 감동적이고 재밌는데
# 5.0
# b급인척하는 a급영화
# 4.0
# 마케팅에 실패한 숨은명작
# 5.0
# 숨겨진 명작이라길래 찾아봤는데... 계속 숨겨둘 걸 그랬다...
# 3.5
# 이런 막무가내와 하드코어 슬랩스틱 같은걸로 웃기려는 시도는 좋아하지 않는다
# 고문하는 장면을 보는것도 괴롭다
# 결말이 좋다고 해서, 매니아들의 평이 좋다고해서 좋은영화가 되는건 아니다
# 4.5
# 나를 왜 괴물로 만든거야?
# 4.5
# 과연 지구에게는 희망이 없는가? B급의 옷을 입은 A급 사회부조리극.
# 3.5
# 아파보면 안다.
# 4.0
# 굉장한 가능성을 만들어낸 영화.
# 하지만 아직은 이런 소재를 다루기엔
# 기술이 부족하다는 것이 현실.
# 4.5
# 2탄을 내놓아 주세요! 리메이크해 주세요!
# 5.0
# 누가 비정상이고 정상일까. 이러한 물음이 전혀 감을 잡을 수 없는 영화의 분위기와 절묘하게 어우려졌다. 과대망상과 연민. 독창성과 괴기스러움의 기묘한 조화. 전무후무한 작품
# 4.0
# 과소평가에 대한 과대평가라는 말도 공감되는 바지만 첫 실험에서 배우들의 역량을 표출시키고 영화만으로 지속적 회자되기란 쉽지 않은 일이다.
# 4.0
# 참 대중적이지 못한 소재를 매력적으로 만든 영화 그 결말이 다소 장난스럽지만 그런 반전에 묘한 카타르시스가 느껴진다
# 4.0
# 이것저것 다 담고도 넘치지 않는 영화
# 5.0
# 명작
# 4.0
# 보기 싫은 외계인들...
# 누가 싸그리 청소해줬으면...
# 4.5
# 포스터에서 느낄 수 없는 의외의 완성도
# 4.5
# 이 영화가 잘못된 홍보로 빛을 못본게 너무 안타깝다
# 이런 영화가 한국에서 만들어진게 신기한데
# 2.0
# 한국 B무비의 걸작
# 5.0
# 숨겨진 명작이란 이유로 과대평가 받는 느낌도 있겠지만 신하균이 미친게 아니라 이 영화 자체가 미쳤다.
# 4.0
# 병맛인 척하는 처절한 계급투쟁 스릴러
# 4.0
# 적절한 병맛이 섞인 명작
# 4.5
# 저평가?  ㅋㅋㅋㅋㅋㅋ
# 2.5
# 이 해에 대단한 한국영화들이 많이 나왔지만 괴작이라면 이 작품. 처절하도록 슬프고 천방지축으로 명랑하고 어이없어 멍하면서도 우리를 되돌아보게 만드는 종잡을 수 없는 느낌의 영화.
# 3.5
# 시대를 앞선 괴작! 미친 배우들의 놀라운 각개 전투!
# 4.0
# 한국형 SF의 대표이자 역대급의 상상력과 넓고 굵직한 메시지의 만남.
# 누가 이 영화를 괴짜라 하는가..
# 3.5
# B급 영화같은 포스터에 진가가 가려져 흥행하지 못한게 안타까울 따름
# 3.0
# 상상력자극
# 4.0
# 코믹인줄알았는데 의외로 뒤로 갈수록 진지해졌고 나중에는 큐브릭의 2001 스페이스오딧세이가 생각이 날 정도였다. B급 영화의 결말 처럼 마무리가 됐지만 그게 더 매력이라 해야하나?
# 4.5
# 포스터의 중요성을 일깨워준 영화. 배우들의 연기가 수준급이어서 아쉬웠던.
# 4.0
# 사실 범작에서 조금 더 나은 수준
# 2.5
# 감독이 외계인인듯
# 3.0
# 재미도 있었고, 신선했지만 너무 잔인해서... 전형적인 영화는 좋으나 내 스타일은 아닌 경우.
# 4.0
# 잼씀 말투 좀 오글거리는데 노동문제
# 2.0
# 실패할수밖에 없는. 그치만 실패한게 의아한 영화.
# 4.0
# 잔인한것만 빼면 좋은데..
# 4.5
# ㅋㅋㅋㅋ 내가 그 반전 보려고 그 긴시간을 투자했다니
# 4.0
# 누가더미쳤나
# 5.0
# 내가 보기엔 과대평가
# 어떤면에서 걸작인지 아직도 의문
# 5.0
# 숨겨진 명작인줄 알고 봤지만 딱 포스터다운 영화.
# 4.5
# 여러가지 생각할 점도 있지만 코미디로도 웃기더라... 때수건에 물파스..ㅜㅜㅜㅜㅜ 상상만해도 아픔 ㅜㅜㅜ
# 4.0
# 쓸데없이 잔인해서 별 한개뺌
# 4.0
# 영화를 뭔 이따구로 만들어? 사람 설레게...
# 3.0
# 소중한 나의 한국영화
# 문소리씨 부러워요...
# 2.5
# 지키고 싶은 영화
# 3.0
# 한국 영화 사상 마케팅팀의 가장 처참한 실패의 기념비로 기억될 걸작.
# 3.0
# 우리지구,, 모두를 끌어안을순없다
# 5.0
# 별로
# 4.5
# 평가 좋길래 기대하고 봤는데 기대 이하
# 5.0
# 야심을 보이려면 영화가 받쳐줘야 한다는 슬픈 진실
# 2.5
# B급 영화는 잘해야 B+
# 1.0
# 스텝롤이 올라올 때, TV에 비춰지는 어린시절 병구의 모습에서 느껴지던 여운이 잊혀지질 않는다. ...호불호가 상당히 갈릴만 한데, 나에겐 최고의 영화 중 하나.
# 2.5
# 신하균이 이런영화에 출연했다고 포스터를보고 역시 신하균이란 말을 끝난후에 생각함
# 5.0
# 신하균 연기의 압권과 더불어
# 감독의 메세지도 훌륭.
# 다만 끝까지 안보면 무슨 내용인지 어리둥절할수도?
# 그러나 영화를 보는 사람의 미덕이 끝까지 보는 거라면
# 굿.
# 5.0
# 아아 신하균의 사이코스러움 너무좋아
# 3.5
# 과소평과 됫다는 이유로 과대평가된..
# 나도 저렇게 리뷰잘하고싶다 ㅎㅎ
# 3.5
# 지구는 지키지 못했지만 영화는 지켰다.
# 4.0
# 최고 짝짝짝짝짝!
# 4.5
# 포스터와 제목의 망테크
# 그것만 아니라면 수작임
# 4.0
# 과소평가된 수작. 그정도
# 3.0
# 다보고나면멍해짐
# 5.0
# 대체 누가 미친놈인가, 병구인가 감독인가, 혹시 내가?
# 5.0
# 처음에 잉 뭐지 하고 봤는데 엄청 놀랐음
# 감독 데뷔작이라 더 놀랬음
# 감독중에 데뷔작으로는 최고인듯
# 3.0
# 여러 장르에 대한 자신의 가능성과 역량을 보여준 데뷔 작품
# 4.0
# 내 멘탈도 좀 지켜줘.....
#
# 골때리는 sf
# 4.0
# 끝까지 보면 너무 놀람
# 2.0
# 미친연기+ B급 영화 위장하고 깊게빠져들게만드는 다양한 트릭을 걸어 놓은듯한 영화
# 5.0
# 생각보다 괜찮은 영화긴한데 고평가에 영화라는거엔 그닥 공감이...
# 4.5
# 그래 마케팅은 이렇게 하면 안되는 거야
# 4.0
# 지금처럼 한국영화가 흥하는 시점에 개봉했다면 천만도 가능했겠다.
# 4.5
# 나는 불호..왜 하필 외계인이란 설정일까
# 3.0
# 완벽하게 나의 B급취향과 들어맞는 몇 안돼는 한국영화중 하나
# 4.0
# 다신 없을 한국 영화 최고의 데뷔작.
# 5.0
# 괴작은 즐겁다. 내 마음대로 해석해도 되거든.
# 3.5
# 신은 장준환 감독에게 영화만드는 능력을 주셧지만 포스터만드는 능력은 깜빡하셨다.
# 4.5
# 그놈의 뻔한 '지구를위협하는건 결국은 인간' 너무나 많이들은 멘트다
# 3.5
# 초,중,종반 모두 색다른 느낌으로 충격을 받았다.
# 1.5
# 말로 표현 못함
# 2.5
# 감독의 상상력에 놀라게 되는 영화. 엉뚱하게 끌리는 묘한 매력의 영화.
# 4.5
# 숨은명작. 하지만 재평가를 받는 지금에서는, 오히려 과대평가 받는것 같은 느낌을 지울 수 없는 영화
# 4.5
# 예상외의 수작
# 3.5
# 이해할 수 없는 현학의 바다
# 5.0
# 쫌 또래이같은영화
# 3.5
# 최고의 반전 신을 외계인으로 표현하고 진화설 또한 재미있는 발상으로 새롭게 표현해넨... 처음엔 무슨이런영화가 있어ㅋ 하다가도 몰입했을때의 마지막 감동은...ㅎ
# 4.5
# 웃기고 이상하고 기괴하고 무섭고 슬프다.
# 이렇게 불편하고 생소한 스토리와 결말을 가진 대중영화가 또 나올 수 있을까?
# 2.5
# 다른 의미로 유명해서 보고 싶었는데 드디어 봤슴.
# 초반의 어이없음이 좀 길어서 그렇지 나중엔 나름 시사점도 있고 좋은데 사장 구출후 엔딩이 좀..-_- B급 컬트영화임
# 3.0
# 영화 속 끔찍한 현실이 십년이 지나도록 나를 억눌렀다. 어디선가 고통 속에 죽어가는 사람들을 우리는 이러저러한 이유로 외면한다. 세월호에 대해 그렇듯.ㅠ
# 5.0
# 포스터로 망한자 포스터로 흥한다
# 3.5
# 싸구려 식당에 기대 안하고 들어갔는데 알고보니 숨은 맛집이었을 때의 기분
# 3.5
# 와...진짜 이상한 영화.
# 5.0
# 네이버 평점이 높기에 기대하고 봄
# 숨은 수작이라 예상.
# 여러가지 메세지를 담았지만
# 섞이지않은 팥빙수 느낌.
# 배우들의 열연 아니였으면 끝까지 집중해서 보기 힘듦.
# 4.0
# 별이 다섯 개 밖에 없어서 더 못 주고 갑니다.
# 4.0
# 상상하라
# 3.5
# 졸작과 수작 그 사이 어딘가에서
# 4.5
# 포스터, 시대, 한국영화의 수준을 30년은 앞서간 영화
# 4.0
# 반전영화의 레전드 오브 전설.
# 3.5
# 신하균님... 연기력!!!!!!
# 5.0
# 기괴하다는 말로도 부족한
# 3.5
# 뭐 이런 듣도 보도 못한 영화가 다있나 엔딩크레딧 다 올라갈때까지 입을 못다물었다 왠지 디스트릭트9이 떠오르네
# 5.0
# 화이 첫 개봉 9시에 이 작품 잔체 관객수를 넘었다지ㅋㅋ 실험적인 작품. 그 때밀이로 밀고 난 후에... 아 내가 다 정신이 나갈 기분
# 4.5
# 알다가도 모를 세상사라는 말이 생각나는 재기발랄한 영화
# 5.0
# 초월적 장르. 생각을 실천에 옮긴 신인감독의 용기.
# 3.0
# 장준환 특유의 알듯 모를듯 한 꼼. 너무 많은걸 의도한건가. 메시지는 엉키고, 사람들의 평가는 극단으로 나뉜다. 모호함과 찜찜함도 특유의 쾌감을 가져오긴 한다만...때론 과유불급.
# 3.5
# '충격'을 받은 몇 안되는 작품. 마스터피스.
# 4.0
# 새로운 장르의 영화를 만났다!!!
# 5.0
# .
# 요즘은 이런영화가 안나온다.
# 신선하고 충격적이고 재미있고 슬픈영화
# 5.0
# 니 본래 이름은?
# 4.0
# 병구의 꿈이 아니었을까
# 4.5
# 포스터의 백어택
# 5.0
# 지구를 지키자!!!
# 5.0
# B급 병맛. 취향
# 4.5
# 각자의 마음 속 양심과 비겁을 동전처럼 뒤집으며 영화를 보면, 놀라운 경험을 하게 될 것이다.
# 4.0
# 죄송합니다 몰라봤습니다
# 4.0
# 이때 장준환감독은 천재 였던듯
# 4.0
# 스릴러의 문법과 B급 코드의 옷을 입은 블랙코미디, 인간을 향한 신날한 세타이어.
# 3.0
# 이게 데뷔작이라고!?
# 4.0
# 한국 블랙코미디의 수작
# 3.5
# 싸이코의 극한을 보여주는 영화
# 3.5
# 범인은 이해 못할 괴작
# 4.0
# 진짜 외계인이라니 당황
# 5.0
# 포스터 만든사람을 잡아다가 줄빠따를 놓고 싶다. 포스터에 속지말고 꼭한번 보시길,,, 여러분들도 포스터 만든사람을 잡고싶어질테니...
# 3.0
# 대한민국에서 20년은 일찍 개봉했다!
# 5.0
# 왕 유치한 듯 하면서도 독특하다
# 영화스러운?
# 그리고 대반전??!!~~ㅋ
# 5.0
# 가능성으로 똘똘 뭉친 영화
# 4.0
# 최고다. 한국에서 이런 영화가 나온게 감사하다.
# 4.0
# 대~박 진짜 외계인이었잖아!
# 3.5
# 웃기다가 무섭다가 슬퍼지는 졸라 비범한 영화. 이 영화 한 편에 대체 몇개의 장르가 들어간 거야?
# 5.0
# 잘못된 홍보가 망친 걸작.
# 4.0
# 정말 참신한 발상과 전개. 끝이 아쉬울 뿐.
# 3.5
# 그냥 설마도 아닌 에이 설마했던 일이 일어났을 때 다가오는 황당함과 짜릿함. B네르기 파!
# 2.0
# 인간을 향한 극단적 염세주의
# 3.0
# 이 영화 재밌음
# 4.0
# 이제 지구는 누가 지키지?
# 5.0
# 획기적이고 신기한 영화. 결국 거짓말이 아니었잖아!!!!!!
# 4.0
# 지구는 지켜야되는데 영화는 안드로메다로...
# 5.0
# 신하균 얼굴 보배롭다….
# 오래 전 봤던 영화라 처음 보는 느낌으로 감상.
# 병구와 류의 삶은 왜이리 비슷하지.. 류도 실험대상자였을까 ㅠ_ㅠ
# 3.0
# 지구를 지키는 이런 안쓰러웅 영웅도 어딘가에 있겠구나
# 2.5
# 최고다
# 4.0
# 뒷통수를 거하게 얻어맞은듯한 멍함.
# 3.0
# 내 망작..
# 5.0
# 가면 갈 수록 늘어나는 억지와 갑자기 엉켜버리는 장르는 마음에 들지 않고,  '왜?' 인가에 대한 설명 하나 제대로 붙여주지 않는 관객을 넘보는 영화.
# 4.0
# 나랑 잘 안맞는듯
# 4.5
# 숨겨진명작!
# 4.0
# 이런 싸이코 무비는 별로야
# 4.5
# 광고컨셉이잘못된듯
# 4.0
# 소름돋는 데뷔작
# 3.5
# b급 몇급보다 진짜 빠져들었다 너무나도 참신한 영화
# 4.0
# 포스터만 좀 더 잘 만들었어도 덜 망했을것을
# 3.0
# 장준환 감독은 천재다
# 4.0
# 이것이 영화스러움.
# 4.0
# 포스터가 잘못했다. 외계인을 믿는 병구 캐릭터가 잘 잡혀서 내내 헛소리한다고 믿을 수 있었다. 불편한 영화를 좋아하는데 취향이 아님. 시사하는 바를 곱씹으면 나쁘지 않음.
# 4.0
# 기발하고 독창적이다. 감독의 역량을 여실히 느낄 수 있는 영화.
# 4.0
# 설익은 연출. 그것을 뛰어넘는 주제의식의 구현.
# 3.0
# 어둡지만 탄탄한 플롯의 훌륭한 독립영화. 저주받은 걸작이라는 말이 적절. 심히 과장된 결말은 아쉽
# 4.0
# 신하균의 연기와 영화가 끝나고 난 이후 찝찝하지만 뭔가 남는 그 느낌
# 5.0
# 제대로 미친 남자의 미완성 복수극.
# 1.5
# 처음엔 무슨 영환가했다. 무슨 말을 하고싶은건가도 궁금했다. 하지만 전체적인 영화의 느낌은 날 신나게 했다!
# 4.0
# 신하균은 언제나 금방이라도 발광할것만 같은 눈빛을 가졌다.
#
# 난 그 모습이 배우라고 느꼈고
# 이 작품에서 여실히, 그는 증명해냈다.
# 3.5
# 포스터.... 포스터만 바꿨어도...
# 4.5
# 웃으면서시작했다가 심각한 우울로 끝나는영화
# 1.5
# 독특한 영화. 그냥 그게 다 다.
# 3.0
# 이게 뒷통수지!!
# 당신은 어디까지 신하균을 믿을 수 있나?
# 3.5
# 음 역시 명작이라고 하기엔 좀...
# 4.0
# 기발하고 튀는게 너무나 넘쳐나 신기하다를 넘어 멋지다.
# 4.0
# 너무 어려웠다.. 다들수작이라고 하는데
# 3.5
# 뭔가독특한발상이돋보였다
# 4.5
# 이 영화 역시 사람들에게 고평가 받는 영화중 하나
# 아님 내가 막눈이거나
# 4.5
# 화이까지 10여년을 기다리게 했던 문제적 데뷔작
# 0.5
# 얼굴은 b급인데 속은 꽉찬 매력덩어리
# 1.5
# 잘나가다가 끝에 조짐
# 마지막 10분만빼면 괜찮은 영화
# 2.0
# 내 인생 최고의 한국형 생활sf
# 4.5
# 특수효과가 조잡해도 주제는 사라지지 않는다.
# 3.5
# 내 아까운 시간
# 4.0
# 연출 쪽으로는 추천
# 5.0
# 코멘트가 날 사기치는건지
# 내가 아직 영화볼줄을 모르는건지
# 4.5
# 하고 싶은 얘기를 하고 싶은 방식대로 할 수 있는 뚝심(과 석연찮은 흥행).
# 4.5
# 어렵다. 누가 이해할 수 있을까.
# 4.0
# 평이 이거 아님 저건데 그럴수 밖에 없는 영화다. 나는 엄청난 호! 다만 홍보를 씨레기 같이 했음은 맞는듯.
# 2.5
# 괴팍하고 정신이상으로 보여지지만 그 속에 우리가 느낄 수 있는 편견과 아픔, 슬픔들을 잘 녹여 표현한 작품이다
# 4.5
# 잔인한데 우습고, 진지한데 말도 안되는 그런 영화. 여러가지로 새롭다. 하균신의 리즈시절♥ 아 미친놈주제에 왤케 잘생겼냐♥
# 4.0
# 블랙코미디의 미학
# 4.5
# 한국식 블랙코미디 속에 현실을 담다
# 3.5
# 뭐지이영화는 이상하게 이상하네
# 4.0
# 기괴한 코메디와 진지함. 전설의 데뷔작.
# 4.0
# 한국 SF에 이런 영화가!!!
# 3.5
# 물파스를 가장 잘 써먹은 영화더라구~
# 3.0
# 지금보아도 당혹스럽다.
# 연민, 그 파괴적인 카타르시스.
# 4.0
# 외쳐봐도 듣지 않는 다수
# 4.5
# 한 사람을 괴물로 만드는게 누군가 했는데... 즐겁기도 하고 끔찍하기도 한데 반전에 뒷통수 한번 더 맞아서 얼얼한 영화.
# 5.0
# 신하균 포에버
# Bittersweet ending
# 2.0
# 잘만든 스릴러
#
# 스릴러치곤 슬프다.
# 4.5
# 천재감독의 패기
# 3.5
# 가벼운 영화가 아니다 신랄하게 까는 영화!
# 1.0
# 폭풍우 같이 흘러가는 미친 시간들이 왜 몇날며칠 주옥같을까? 물파스 사둬야겠다. 나사가 하나 빠져서 완벽한 영화. 딱 우리 꼬라지 같다.
# 5.0
# 시대를 잘못 탔다 포스터가 망쳤다 등의 평으로 기대 많이 했는데 그저 팬심으로 끝까지 봄
# 4.5
# 겁나 매력적인 영화
# 괴작이고 명작이고 평가하기 전에 흡입력 있는 영화인건 확실하다.
# 3.5
# 뭐지 이 병신같은 전개는?
# 5.0
# 파스 장면은 아직도 생생함.
# 5.0
# 이거 인생영환데 홍보를 너무 유치하게 해서 망했어 ㅜㅜ 재개봉해야돼
# 4.5
# 최고의 블랙코미디.
# 너무나 많은 것들을 다루고 있다.
# 포스터만 보고 판단하지 마시길.
# 4.5
# 뭐지..이 ㅂㅅㅁ 넘치는 영화는..
# 4.5
# B급 코드의 독창적 전개
# 3.5
# 계속 생각날거같아..
# 4.0
# 숨겨진 수작.
# 4.0
# 우리나라에서 가장 괴상하고 앞으로도 보기힘든 걸작
# 3.5
# 가슴이 터질듯 격동하다가 허탈하게 웃고, 씁쓸하고 슬픈 마음을 밤새도록 곱씹었다
# 3.5
# 광고만 잘했더라면
# 4.5
# 볼때는 그냥 그랬다가 생각할수록 굉장한 영화라고 느껴지는 마법
# 4.5
# 이상한데 멋있다.
# 4.0
# 웃으려고 보고 실컷 웃으면서 보다가 마지막엔 우울해져버린다.
# 4.5
# 반전에 초점을 두지만 사실 메시지가 더 강력한 영화. 다만 불필요한 (그리고 재미 없는) 블랙코미디는 흠
# 5.0
# 코미디의 탈을 쓴 훌륭한 수작! 하지만 포스터가 관객을 놓친 영화!
# 3.5
# 이영화로 인해 2000년부터 우리 영화발전의 시작인줄 알았음
# 이것으로 끝일줄이야ㅠㅠ
# 3.0
# 마케팅의 중요성이 얼마나 대단한지 세삼 깨닫게되는 영화.
# 3.5
# 천재 감독의 극적인 데뷔작.
#
# 표면적으론 B급 처럼 보이지만, 그 속에 숨겨진 어마어마한 메시지와 울림.
# 4.0
# 병구는 도대체 왜.
# 4.5
# 물파스 ㅋㅋ 굿이에요!!!
# 4.0
# 취향이 갈리는 영화이기 전에 이주현의 연기 때문에 몰입하기가 힘들었다.
# 4.0
# 러닝타임 내내 영화가 뭘 말하고 싶어하는지 생각하다가 뒷통수를 한대 얻어맞았다. 그러나 결국 영화는 무엇을 말하려 하는가의 문제다
# 5.0
# 포스터가 영화랑 전혀상관없음 그러니 흥행실패지 개그코드와 포스터만보고 영화를본다면 뒤통수맞은거 신하균이잖아 신하균
# 4.5
# b급의 a스러움
# 4.0
# 대중성이 없다는 것이 제일 아쉬운
# 4.5
# 21세기 시작을 여는 한국영화 최고의 괴작. 백윤식옹에게 경배를!
# 4.5
# 이런 스릴러가 한국에서 다시 나올수 있을까?
# 3.0
# 한국영화의 숨겨진보석!
# 3.5
# 장준환은 천재인가 아님  또라이인가
# 3.5
# 알고보면 처음부터 반전따윈 없었던 영화.  감독의 신랄한 연출과 배우들의 연기가 기억에 남는다
# 4.0
# 다 안다고? 다 알수도 있겠지 뻔한 이야기니깐 그런데 다 안다면서 뭘했는데? 고통받고 있었을 때 뭘했어? 니들이 더 나빠
# 4.5
# 미친 사람들이 미친게 아닐지도 모른다는 생각. 비정상과 정상의 기준이 틀릴지도 모른다는 생각을 하게된다. 영화 자체는 괴작인데 개인적인 해석은 명작.
# 5.0
# 생각지도 못한 반전
# 4.0
# 데뷔작에 너무 많은 것을 담으려 했다. 과유불급. 그리고 화이에서도 느낀거지만 감독이 말이 많으면 매력없다.
# 4.0
# 재기발랄 했었음
# 4.0
# B급 똘기가 가득한 A급 영화
# 4.5
# 비유와 은유의
# 시대를 앞서간 명작...
# 5.0
# 충격적이며 기괴한 장준환 감독의 데뷔
# 이후의 행보를 보면 재능이 너무 아깝다
# 4.5
# 모든 가능성을 열어두고 살자. 내 옆에서 일하는 김대리도 외계인일지도 모른다.
# 3.5
# 한국에서는 볼 수 없었던 독특한 상업영화
# 3.5
# 미친 세상에서 병구가 살아남는 법
# 3.0
# 새로운 도전에 성공한 감독에게 박수를
# 4.0
# 2003년은 한국영화의 전성기였다
# 4.0
# 한국영화의 저주받은 걸작.
# 3.0
# 아... 어렵도다... 이 영화의 별점을 메기는 것이 의미가 있을까?
# 영화에 집중하면 뇌리를 강타하는 느낌을 받지만
# 조금만 흐트러져도 삼류 싸이코 물이 되어버리는 영화.
# 3.0
# 결말 맘에 안듬 ㅡㅡ
# 4.5
# 너무 똑똑해서 손해보는 감독의 너무 지능적인 영화.
# 델리카트슨의 여운이 느껴진다.
# 4.5
# 가슴이 먹먹하다. 현실과 비현실, 상식과 비상식의 경계가 모호한 현실세태.
# 5.0
# 영화는좋았지만 험한걸 봐야해서
# 4.0
# 투박한 영상 신선한 이야기의 괴작.
# 3.5
# 어쩌면 가장 개성적인 한국 영화.
# 4.0
# 한국 최고의 코미디 영화.
# 5.0
# 정말 독특한영화. 예상외의 반전
# 4.0
# 터지는 상상력을 감추지않은 잊지못할 데뷔작
# 4.0
# 확실히 괴작이긴 괴작이네
# 4.5
# 포스터 때문에 피 본영화 1위
# 4.5
# 코미디나 에스에프인줄 알았다면 큰 오산
# 4.5
# 기발하게 시작해서 기똥차게 끝나는 슬픈 코미디. 다시는 이런 톤엔 매너가 나올 수 있을까
# 4.0
# 잼나 잼나. 특이특이. 내 스탈 개그 ㅋㅋㅋ
# 4.0
# 기발하고 독특한 상상력으로 충무로의 신선한 충격을 가져다 준 장준환 감독의 인상적인 처녀작.
# 0.5
# 걸작이라고 생각하고 정말 좋았지만 두 번은 못보겠다. 너무 힘들어 ㅠㅠ
# +
# 홍보에 속지 마세요. 정말 힘든 블랙 코미딥니다. 웃기지만 정신이 피폐해져요 ㅠㅠ
# 4.5
# 충격과 충격. 그리고 충격
# 5.0
# 다른생각
# 3.0
# 포스터가 오덕냄새가 나서 망한느낌
# 병맛같지만 물파스처럼 시원하고 묘한 설득력이 있다
# 4.5
# B급이겠거니 하고 봤지만 어라 싶다가 역시나 하는 영화.
# 3.0
# 명작과 수작이라는 말보단 도전이라는 말을
# 4.5
# 기발한 영화.감독의 머릿속이 궁금해질 정도로.그리고 잊을수 없는 때밀이와 물파스의 궁합!
# 4.0
# 장르를 파악할 순 없었지만, 무엇을 이야기하는지는 확실하다.
# 4.0
# ㅋㅋㅋㅋ 포스터 어떻할거야
# 5.0
# 유쾌하진않지만,
# 유쾌한척하는 영화
# 5.0
# 포스터때문에 망한 수작...하균신의 연기의시작!
# 4.0
# 또라이같지만 멋있다는 말은 이 영화를 위한 말이다. 이 정신나감의 깊이감에 감탄한다.
# 3.0
# 너무 잘 만들어서 망한영화
# 3.0
# 최고의 배우, 최고의 스토리, 최고의 연출, 최악의 포스터.
# 현실과 착각의 경계에서 위태로운 싸움
# 3.0
# 퀘뿡쒜터럽~~~무서운 때밀이수건!!
# 5.0
# B급 영화? 절대
# 3.5
# 너무 어렸을 때 본 영화
# 지금보면 다를려나?
# 5.0
# 진짜 중요한 주제를 너무나 기발하게 표현한 영화..
# 다만 그 기발함을 보통 사람들이 받아들이기에 가능한가에 대하 의문이 남는다
# 5.0
# 뭔말인 지 알겠고, 왜 저주받은 걸작이라고들 하는 지 알겠고. 하지만 내가 보기론, 그냥 저주받은 평작 그 이상 그 이하도 아니다
# 2.5
# 진짜 대단한 영화라고는 말밖에는 할수없는영화
# 신하균의 연기며 각본이며 이런 영화가 흥행하지 못했던 이유중에 하나는
# 포스터 때문이다 나도 포스터보고 안보려고했으니깐
# 4.0
# '조금 늦게 기획되서 조금 더 자극적이고 노골적인 연출, 더 많은 제작비가 투입됬다면 어땟을까' 하는 미련이 남는다. 장준환 감독이 더 많은 작품활동을 하길 소망한다.
# 5.0
# 이 정도 상상력에 반전에 메세지까지 최고의 데뷔작
# 3.0
# 한국영화중에 다섯개를 꼽으라 하면 단연 꼽을 수 있는 수작.  중학교때 보았는데.  그당시 적잖은 충격이였다
# 2.0
# 괴작이든 걸작이든 망작이든
# 문제작임은 확실하다
# 4.0
# 마케팅의 중요성을 일깨워준 명작.
# 4.0
# 저주받은 걸작
# 5.0
# B 급 영화라 생각 되지 않을 정도로 출중한 연기와 연출! 훌륭한 블랙코미디지만 취향을 많이 탈듯
# 5.0
# 높이 평가를 받는 영화? 과반수의 관객에게 메세지를 잘 전달시킬수 있는것도 필요한 법이다. 이기적이잖나? 자신의 색만 강하게 칠하는것은...
# 3.0
# 이런 B-급 너무 좋다
# 5.0
# 이건 진짜 괴작이다
# 5.0
# 우리나라 SF영화 중 최고. 마지막 장면이  관객을 조롱한다.
# 4.0
# 열번 넘게 본듯..
# 5.0
# 영화를 이해하기엔 네가 너무 모자라다.
# 4.0
# .....ㅠㅠ이건리얼리즘이다
# 4.0
# 인생 최고의 영화.
# 5.0
# 재미있다.메시지는 다소 무겁지만 이렇게 풀어가는 것도 나쁘지 않는듯
# 2.0
# 이게 처녀작인 감독의 뇌는 연구대상
# 5.0
# 처음에 포스터 얼핏 봤을때 유세윤인줄.....
# 5.0
# 지구를 못지켰다.  별점 -1
# 4.0
# 와.....
# 5.0
# 남들에게는 수작, 명작이지만 나한테는 그닥..
# 4.0
# 신하균을 향한 팬심으로 보기 시작했고, 볼때는 이보다 난해한 영화가 또 있을까 했지만, 영화가 끝나고 나서는 이 작품이 제목과 포스터 때문에 저평가되었다는 사실이 안타까웠다
# 4.0
# 이 나라에서 장르영화가 천대받긴 하지만, 난 장르 영화가 좋아. 헛점이 많아도 장르적 개성은 백점인 영화. 쉽게 말해서 호불호가 갈리는 영화.
# 4.0
# 어릴적 받았던 충격 외계인은 존재한다!!!!!!!!
# 5.0
# 병구야.......
# 3.5
# 마지막 반전이 소름끼쳤다
# 2.0
# 대기업 나빠
# 2.5
# 포스터때문에 망한 걸작? 그런얘기들 땜에 너무 기대하고 보진 말길.
# 제일 마음에드는건 독특하고 애매모호한 장르ㅋㅋㅋㅋㅋ
# 4.5
# 대한민국의 숨겨진 명작 1위 영화.
# 3.0
# 참신함에게
# 4.0
# 재평가해야한다고 많이 추천받았으나
# 왜 묻힌줄 알겠음
# 개인적으론 상당히 실망함
# 5.0
# 과소평가된 수작이라해도 한가지 분명한건 졸라 재미없음.
# 3.0
# 이렇게 저렇게 현실을 비틀려다보니 너무 꼬이고 엉켜서 매듭을 풀 엄두도 못내고 그냥 불태워버렸다. 조금만 더 차분했으면 명작이 될 수도 있었을 텐데...
# 5.0
# 이건 코미디야 스릴러야??
# 5.0
# 흥행.안된게.아쉬운.수작. 감독의 뇌를.열어보고 싶음..
#  우리나라에서 보기.힘든.블랙.코미디
# 4.0
# 나에겐 최고!
# 1.5
# 독특함.
# 3.0
# 숨은명작. 유치함 속에 들어있는 신랄함.
# 5.0
# 한국 관객들의 일반적 취향에
# 맞지 않는다는것이 문제일뿐.
# 1.0
# 앞으로 한국에서는 절대 나올 수 없는 영화
# 5.0
# 자극적이기만
# 3.5
# sf영화를 참신하게 표현한것과 황당과 공감을 동시에 표현하는등 생각해보면 장점만 생각나지만 왜 안끌리는지...왜안끌리는지 이유찾는게 너무힘들다
# 4.0
# 최고였어요^^
# 4.0
# 뭐지?
# 5.0
# 포스터만 놓고보면 마냥 코미디영화
# 4.0
# 워낙 '숨겨진 명작'이라는 명성이 기대감을 높여놔서 조금 실망은 했지만, 독특한 스릴러
# 5.0
# 시대가 알아주지 못한 수작
# 4.0
# 코믹적인 설정 뒤에 숨겨진 병구의 처참한 현실을 기괴하고도 신선하게 연출했다. 그는 왜 그토록 지독하게 지구를 지키고싶어 했을까? 코믹sf의 가면을 쓴 사회풍자영화.
# 5.0
# 장준환 기억하겠습니다
# 4.0
# 모순된 세상의 모든 아픔을 다 겪은 병구... 엔딩크레딧이 올라갈때 티비에 나오는 화면을 보면서 가슴이 무겁고 답답함을 느꼈다.
# 5.0
# 뻔하지 않는 휴머니즘 시대를 잘못 태어난 작품
# 3.0
# 처음입니다. 이 영화를 처음서 부터 다 본것은..
# 좋아하는 장르인데 더욱 발전했으면 좋겠네요..
# 5.0
# 스릴러 코믹 공포 음모 액션 형사물을 완벽하게 섞은 걸작!
# 4.5
# 지구는 내가 지킬게 병구
# 4.0
# 의외의 영화 한국b급영화의 걸작
# 5.0
# 병맛
# 4.0
# 고1때 우연히 보다가 완전 빠져버렸던 영화인데 벌써 몇 번이나 봤지만 볼때마다 느낌이 다르고 볼때마다 씁쓸해 진다
# 지금 다시 봐도 역시 내 인생 최고의 수작 걸작 명작이다
# 5.0
# 많이 아쉽긴한데 한국에서 이렇게 잘 만든 B급영화가 없다.
# 5.0
# 포스터가 다 망쳐버린 눈물나는 걸작
# 4.0
# 이 영화가 묻히다니 지구가 통곡한다
# 4.0
# 전설적 대뷔작
# 5.0
# 괴기한 줄거리와 좀 덜 다듬어진 미장센
# Raw의 연출
#
# 그런데 블렌딩 된 완제품을 보니
# 최고급 호텔 요리.
# 5.0
# 2012. 잔인한 것은 우리가 사소한 것으로 생각하는 것.
# 5.0
# 와, 뭐지. 우리나라 영화맞아?
# 5.0
# 그놈의 포스터때문에...
# 5.0
# 불편한 영화가 친절한 영화보다 더 오래토록 여운이 남는다는 걸 알려준 영화.
# 5.0
# 삼류영화!???  노노 내가본 국내 영화중 다섯손가락에드는 명작!
# 천재 장준환에 데뷔작
# 영화 홍보가 영화를 망쳤다ㅜㅠ
# 3.0
# 장준환이라는 돌연변이를 만들어낸
# 한쿡 땡큐!
# 3.0
# 모래알속 숨겨진 진주같은 영화
# 4.0
# 이게 바로 숨은 명작이지
# 4.5
# 최고의 영화라고 생각합니다. 코미디 영화가 아닙니다.
# 5.0
# 명작임을 드러내지 않으려 노력하는 이상한 영화
# 4.0
# 포스터상단문구와 교묘한장면짜집기에 신나는배경음악이조화된 예고편에속아 킬링타임용 코미디구나! 하고보면 큰낭패당하는 영화
# 5.0
# 사람이 만든 외계인
# 5.0
# 엄청난 의미를 담고있는 대작.
# 5.0
# 이건 장준환 감독만 만들 수 있는 영화다. 장준환, 이 미친 인간.
# 4.0
# 최고의 데뷔작이자 최악의 홍보.
# 만화경같은 영화. 독특한 연출과 처절한 배우들의 연기 그리고 약빤 이야기. 한국에서 다신 못 나올 것 같은 데뷔작
# 2.0
# 언제봐도 신선한 영화
# 4.5
# 진짜 기대없이 봤다가 반했다. 최고!! 배우들 연기도 잘하고 내용도 신선하고 네번정도 본듯
# 2.5
# 숨겨진 보석.
# 5.0
# 코믹으로 홍보한 것이 아쉽지만 페이소스가 있는 영화다.
# 5.0
# 하이고.. 그냥 병맛.
# 보지마세요
# 3.0
# 이런 영화 처음 봤다.
# 보고싶어요
# 괴기스러워 보기 쉽지 않았으나 수작임은 분명
# 4.0
# 시대를 잘못 만난 괴작. 그리고 영화홍보가 얼마나 중요한지를 보여주는 저주받은 걸작.
# 한국영화 사상 가장 발칙한 소재와 연출이 돋보이는 최고의 명작.
# 5.0
# 너무나도 치밀한 영화다. 이 세계자체가 코믹스러울 정도로 주인공의 노력은 처철하기까지 하다. 마케팅의 실패가 뼈 아프지만 한국 영화에 한 획을 그었다고 본다
# 4.0
# 떡밥회수하셔야죠
# 4.0
# 어제 더굿무비에서 이동진씨가 설명해주시는거 보고 이영화에 대한 생각이 확바꼈음 예전에 포스터만 봤을때는 그냥 전형적인 우리나라코미디라 생각하고 안봤는데...포스터를 왜저따구로..
# 5.0
# 과연 저주받은 걸작
# 5.0
# 영화를 죽인 포스터
# 2.0
# 제발 괜찮은 영화 포스터 좀 이따위로 만들지 마라. 신하균이 정말 잘했다.
# 5.0
# 본격 포스터가 말아먹은 영화
# 2.0
# 보편적 형식에 익숙한 나에게 새로운 체험을 안겨준 숨겨진 보석같은 영화.
# 5.0
# 최고다. 포스터보고 그냥 지나칠뻔했는데
# 안봤음 후회했을거같다.
# 제일 재밌게 본 영화 중 손꼽힌다.
# 5.0
# 남들은 숨겨둔수작이라고하지만 난그냥 쓰레기같음..
# 4.0
# 내가 제일 좋아하는 한국영화. 엔딩이 진짴ㅋㅋㄱㄱ
# 2.0
# 명작이라도 그렇지. 내만재미없었나... 영화라면 그래도 재미는있어야지
# 4.5
# 포스터가 망친 영화. 신하균은 진짜 미친거 같다.
# 2.5
# 홍보 실패의 좋은예. 직접 봐야함.
# 4.0
# 마케팅이 망친 영화
# 4.0
# 저주받은 걸작이라는 평이 많던데, 저주 받을 만 했다
# 4.0
# 황당한 설정이 오히려 영화의 메시지에 무게감을 불어넣다.
# 5.0
# 나와는 그닥 맞지 않았던 영화
# 4.0
# 실험적 영화 !
# 3.0
# 포스터가 영화를 망친 좋은예
# 4.0
# 이래저래 디테일이좋은영화
# 5.0
# 진심 내용이 비현실적이면서도 현실이 들어가있다....  아 진심 어떻게 하면 저런 연기가 나오지...
# 5.0
# 코메디가 아닙니다..
# 4.0
# ㅋㅋㅋㅋㅋㅋ 그저 웃지요 ㅋㅋㅋ
# 연기파들의 제대로된 미친코믹연기
# 신하균, 돌+아이 연기 최고, 백윤식의 캐릭터 넘치는 연기도 굳! 고로 연기는 좋았지만 영화는..
# 3.0
# 왜 코미디로 홍보를 했을까 ㅜㅜ
# 4.0
# 한국에서 다신 볼 수 없을 스토리와 반전을 보여 준 웰메이드 영화.
# 5.0
# 이 영화는 별 한개와 다섯개로 나뉘는것 같다..난 다섯개!!똘아이를 위한 최고의 영화!!
# 5.0
# 병구(신하균)를 보면 왠지 안쓰럽고 짠하다.
# 3.5
# 미안, 전 외계인에 관심이 없어서.
# 5.0
# 물파스와 때밀이
# 5.0
# 당시 시대를 너무 앞섰던 숨은 명작.
# 5.0
# 동화적이면서 현실적인, 가장 순수했기에 가장 잔혹한
# 4.0
# 깨알같은 재미 신하균의 연기도 굿굿
# 5.0
# 영화포스터가망가뜨린불후의명작
# 5.0
# 한국영화의 최고
# 5.0
# 포스터에 속지말자!!!
# 3.0
# 그래가꼬 지구 지키긋나?
# 4.0
# 난 왜 이영화가 존나 재밌지? 평이 극심하게 엇갈리는영화의 대표
# 5.0
# 진심 한국에서 이런영화가 만들어 졌다는게 놀라울 뿐이다
# 5.0
# 장준환 감독은 천재 아니면 또라이
# 5.0
# 내용이 너무.참혹해서 별 하나 짜름 ㅋㅋ
# 5.0
# 잔인한 장면의 고수위는 맘에 썩 들지않는...
# 4.0
# 홍보가 잘못했네
# 5.0
# 장준환 감독의 시나리오가 영화개봉 전부터 심상치 않다는 소문이 들려왔었다.
# 시나리오만으로도 충분히 매력있는 작품
# 4.0
# 처절하게 본 기억이... 마지막반전은 식스센스 뺨따구쉐리
# 5.0
# 작은 화면에 너무나도 큰 이야기를 담은
# 감독의 능력이 놀랍다!
# 5.0
# 이렇게 유쾌한 엔딩이라니.
# 4.0
# 가장 한국다운 SF 새드무비.
# 모든 이야기가 슬프고 아름답다.
# 5.0
# 판타지와 현실은 한끗 차이다.
# 5.0
# 정신분열을 다룬 슬픈 현실 영화
# 4.0
# 최고에요!
# 4.0
# 거짓된 진실
# 4.0
# 옷 갈아입었는데 주머니에서 만원짜리 나온느낌... 이건 봐야 돼요!! 포스터좀 잘만들지..
# 4.0
# 구타유발자와 더불어 비운의 명작.
# 4.0
# 어찌 보면 마치 이말년스러운 영화가 아닐까? 기승전병의 맛이 좋은 독특한 영화.
# 5.0
# 이 영화는 엄연한 SF영화이다.
# 5.0
# 정말 좋은 영화인데 이 영화는 포스터에서 망했음!
# 4.0
# 한국 최고의 SF영화
# 5.0
# 이렇게 예측불허한 영화는 처음이야... 한 번 보기 시작하면 멈출 수 없는 영화 좀 낯선 느낌이지만 궁금해서 못 참는다
# 3.0
# 이 영화는 진짜 봐야함
# 4.0
# 이 영화는 봐야한다.
# 3.0
# 말그대로 숨겨진 명작
# 4.0
# 영화는 이렇게 만들어야지. 살인의 추억과 함께 최고의 한국 영화.
# 5.0
# 사회적 소수자들에 대한 위치를 절실하게 느끼게 해준 영화 하지만 불쾌한 연출들이 많아서 불편했다
# 4.0
# 포스터가 망친 영화라고 할 수 있음
# 5.0
# 은근꿀잼
# 5.0
# 발칙한 상상력... 정말 괜찮은 작품임에도 사람들에게 그리 좋은 평가를 받지 못하는 것 같아서 안타깝다..
# 4.0
# 숨은 명작인데 묻혀서 너무 아쉬움
# 5.0
# 장준환의 충격적인 데뷔작
# 3.5
# 우리나라 영화중 내가 좋아하는 Top 10안에 들만한 영화.. 한국형 SF 진정.. 좋음. 냐하하
# 5.0
# 영화 초반부 물파스씬 그거 진짜로 찍은거래요 ㅋㅋ
# 5.0
# 이 영화 포스터 만든 사람이랑 마케팅 담당했던 사람들 다 옷 벗어야 한다. 뒤틀린 자의 슬픈 스릴러를 코미디로 만들어버리다니.
# 5.0
# 끝까지봐라
# 4.0
# 이 영화 마케팅한사람은 신하균한테 고문당해야한다.
# 5.0
# 참신함!!!!!!
# 5.0
# 설마...
# 4.0
# 개후덜덜 말도 안되는 영화
#
#
#
#
#
#
#
#
#
# 3388

# %%
import pandas as pd

result_excel = pd.DataFrame(result)
result_excel.to_excel(excel_writer='sample.xlsx')
